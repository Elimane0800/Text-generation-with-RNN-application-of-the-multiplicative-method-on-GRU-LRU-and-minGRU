# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
nltk.download("punkt")
from sklearn.model_selection import KFold
nltk.download("stopwords")
nltk.download("wordnet")
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
import tensorflow as tf
from tensorflow.keras.layers import Input, Embedding, SimpleRNN, Dense, GRU, Activation, LSTM, Bidirectional, MultiHeadAttention, Concatenate, Dropout, Add, Lambda, BatchNormalization
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers.legacy import Adam, RMSprop
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.optimizers.schedules import CosineDecay
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import os
import re
#from gensim.models import Word2Vec
import plotly.express as px
import keras.backend as K
from keras.regularizers import l2
from keras.callbacks import EarlyStopping
from scipy.stats import entropy
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/yassineseidou/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/yassineseidou/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/yassineseidou/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Lire le fichier texte et ajouter toutes les lignes dans une liste
with open("fleurs_mal.txt", 'r' , encoding = 'utf8') as f:
    lines = f.readlines()

df = ''.join(lines)

tokens = word_tokenize(df.lower())
print("There are :",len(tokens), "words in the document")
print("There are :",len(set(tokens)), "unique words in the document")
# Out:
# There are : 32562 words in the document
# There are : 6975 unique words in the document

# %% [markdown]
# ## Analyse Exploratoire

# %%
plt.figure(figsize=(20,20))
wc = WordCloud(max_words=100,
               height=800,
               width=1600,
               ).generate(df)
plt.imshow(wc, interpolation="bilinear")

# visualize the distribution of number of words in a text

fig = px.histogram(x = [len(x) for x in tokens], nbins = 100)
fig.show()

# %%
stop_words = stopwords.words('french')
#stop_words.extend(['from', 'subject', 're', 'edu', 'use', 'le', 'la', 'du', 'des', 'un', 'une', 'a'])
stop_words
# Out:
# ['au',
#  'aux',
#  'avec',
#  'ce',
#  'ces',
#  'dans',
#  'de',
#  'des',
#  'du',
#  'elle',
#  'en',
#  'et',
#  'eux',
#  'il',
#  'ils',
#  'je',
#  'la',
#  'le',
#  'les',
#  'leur',
#  'lui',
#  'ma',
#  'mais',
#  'me',
#  'même',
#  'mes',
#  'moi',
#  'mon',
#  'ne',
#  'nos',
#  'notre',
#  'nous',
#  'on',
#  'ou',
#  'par',
#  'pas',
#  'pour',
#  'qu',
#  'que',
#  'qui',
#  'sa',
#  'se',
#  'ses',
#  'son',
#  'sur',
#  'ta',
#  'te',
#  'tes',
#  'toi',
#  'ton',
#  'tu',
#  'un',
#  'une',
#  'vos',
#  'votre',
#  'vous',
#  'c',
#  'd',
#  'j',
#  'l',
#  'à',
#  'm',
#  'n',
#  's',
#  't',
#  'y',
#  'été',
#  'étée',
#  'étées',
#  'étés',
#  'étant',
#  'étante',
#  'étants',
#  'étantes',
#  'suis',
#  'es',
#  'est',
#  'sommes',
#  'êtes',
#  'sont',
#  'serai',
#  'seras',
#  'sera',
#  'serons',
#  'serez',
#  'seront',
#  'serais',
#  'serait',
#  'serions',
#  'seriez',
#  'seraient',
#  'étais',
#  'était',
#  'étions',
#  'étiez',
#  'étaient',
#  'fus',
#  'fut',
#  'fûmes',
#  'fûtes',
#  'furent',
#  'sois',
#  'soit',
#  'soyons',
#  'soyez',
#  'soient',
#  'fusse',
#  'fusses',
#  'fût',
#  'fussions',
#  'fussiez',
#  'fussent',
#  'ayant',
#  'ayante',
#  'ayantes',
#  'ayants',
#  'eu',
#  'eue',
#  'eues',
#  'eus',
#  'ai',
#  'as',
#  'avons',
#  'avez',
#  'ont',
#  'aurai',
#  'auras',
#  'aura',
#  'aurons',
#  'aurez',
#  'auront',
#  'aurais',
#  'aurait',
#  'aurions',
#  'auriez',
#  'auraient',
#  'avais',
#  'avait',
#  'avions',
#  'aviez',
#  'avaient',
#  'eut',
#  'eûmes',
#  'eûtes',
#  'eurent',
#  'aie',
#  'aies',
#  'ait',
#  'ayons',
#  'ayez',
#  'aient',
#  'eusse',
#  'eusses',
#  'eût',
#  'eussions',
#  'eussiez',
#  'eussent']

# %%
len(stop_words)
# Out:
# 157

# %% [markdown]
# ## Traitement du texte

# %%
# Initialisation du lemmatizer
lemmatizer = WordNetLemmatizer()

def preprocess_text(text, stop_words):
    """
    Nettoie et prétraite le texte :
    - Met en minuscule
    - Supprime les caractères spéciaux
    - Tokenize
    - Retire les stopwords
    - Lematise les mots restants
    """
    # Convertir en minuscule
    text = text.lower()
    
    # Supprimer les caractères spéciaux (on garde les mots uniquement)
    text = re.sub(r"[^\w\s]", "", text)
    
    # Tokenization
    tokens = word_tokenize(text)
    
    # Retirer les stopwords
    tokens = [word for word in tokens if word not in stop_words]
    
    # Lemmatisation
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens]
    
    return lemmatized_tokens

# %%
# Appliquer la fonction au corpus
preprocessed_tokens = preprocess_text(df, stop_words)

# %%
# Vérifier les résultats
print("Exemple de tokens prétraités :", preprocessed_tokens[:50])
print("Nombre total de mots après prétraitement :", len(preprocessed_tokens))
print("Nombre de mots uniques après prétraitement :", len(set(preprocessed_tokens)))
# Out:
# Exemple de tokens prétraités : ['the', 'project', 'gutenberg', 'ebook', 'of', 'fleurs', 'mal', 'by', 'charles', 'baudelaire', 'this', 'ebook', 'is', 'for', 'the', 'use', 'of', 'anyone', 'anywhere', 'at', 'no', 'cost', 'and', 'with', 'almost', 'no', 'restriction', 'whatsoever', 'you', 'may', 'copy', 'it', 'give', 'it', 'away', 'or', 'reuse', 'it', 'under', 'the', 'term', 'of', 'the', 'project', 'gutenberg', 'license', 'included', 'with', 'this', 'ebook']
# Nombre total de mots après prétraitement : 18235
# Nombre de mots uniques après prétraitement : 6654

# %%
plt.figure(figsize=(20,20))
wc = WordCloud(max_words=100,
               height=800,
               width=1600,
               ).generate(" ".join(preprocessed_tokens))
plt.imshow(wc, interpolation="bilinear")

# Distribution de la longueur des textes après prétraitement
fig = px.histogram(x=[len(x) for x in preprocessed_tokens], nbins=100)
fig.show()

# %%
# Convertir les tokens en texte (si besoin pour d'autres étapes)
cleaned_text = " ".join(preprocessed_tokens)

# %%
for idx, line in enumerate(preprocessed_tokens):
    if "Charles Baudelaire" in line:
        first_line = idx
    if "End of the Project" in line:
        last_line = idx

# %%
first_line = None
last_line = None
lines = lines[first_line:last_line]
lines = [l.lower().strip().replace('_', '') for l in lines if len(l) > 1]
text = " ".join(lines)

# %%
characters = sorted(set(text))
n_characters = len(characters)

# %%
n_characters
# Out:
# 72

# %%
# SEQLEN représente la taille de la séquence de lettres à passer en entrée
SEQLEN = 10
step = 1
input_characters, labels = [], []
# On parcourt le corpus de texte avec une fenêtre glissante
for i in range(0, len(text) - SEQLEN, step):
    input_characters.append(text[i:i + SEQLEN])
    labels.append(text[i + SEQLEN])

print(f"Il y a {len(input_characters)} séquences de {SEQLEN} caractères dans le corpus d'entraînement.")
# Out:
# Il y a 165482 séquences de 10 caractères dans le corpus d'entraînement.

# %%
# Encodage caractère -> indice du dictionaire
char2index = dict((c, i) for i, c in enumerate(characters))
# Encodage de l'indice vers le caractère (utilisé pour décoder les prédictions du modèle)
index2char = dict((i, c) for i, c in enumerate(characters)) # mapping index -> char in dictionary

# %%
# Initialisation des tenseurs
X = np.zeros((len(input_characters), SEQLEN, n_characters), dtype=bool)
y = np.zeros((len(input_characters), n_characters), dtype=bool)

# Remplissage des tenseurs X et y
for idx_seq, sequence in enumerate(input_characters):
    for idx_char, char in enumerate(sequence):
        # Encode chaque caractère dans une représentation one-hot
        X[idx_seq, idx_char, char2index[char]] = 1
    # Encode le caractère cible correspondant
    y[idx_seq, char2index[labels[idx_seq]]] = 1

print("Encodage terminé.")
print(f"X shape: {X.shape}, y shape: {y.shape}")
# Out:
# Encodage terminé.
# X shape: (165482, 10, 72), y shape: (165482, 72)

# %%
#from sklearn.model_selection import train_test_split

# 80% des données en apprentissage, 20% en validation
#X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=0)

# %% [markdown]
# ### Model

# %%
class CosineAnnealingScheduler(Callback):
    def __init__(self, max_lr, min_lr, total_epochs):
        super(CosineAnnealingScheduler, self).__init__()
        self.max_lr = max_lr
        self.min_lr = min_lr
        self.total_epochs = total_epochs

    def on_epoch_begin(self, epoch, logs=None):
        # Calcul du nouveau learning rate
        cosine_lr = self.min_lr + 0.3 * (self.max_lr - self.min_lr) * (
            1 + np.cos(np.pi * epoch / self.total_epochs)
        )
        
        # Mise à jour du learning rate de l'optimiseur
        K.set_value(self.model.optimizer.lr, cosine_lr)

        print(f"Epoch {epoch+1}: Learning rate is {cosine_lr:.6f}")

# %%
# Paramètres
h_size = 128
dropout_rate = 0.2
weight_decay = 0.0001
batch_size = 128
num_epochs = 20
initial_learning_rate = 0.001
k = 10  # Nombre de folds pour la validation croisée

# Définition de l'entrée
inputs = Input(shape=(SEQLEN, n_characters))

# Construction du modèle avec skip connections
x = GRU(h_size, return_sequences=True, kernel_regularizer=l2(weight_decay), unroll=True)(inputs)
x = BatchNormalization()(x)
skip_1 = x

x = GRU(h_size, return_sequences=True, kernel_regularizer=l2(weight_decay), unroll=True)(x)
x = BatchNormalization()(x)
x = Add()([x, skip_1])
x = Dropout(dropout_rate)(x)
skip_2 = x

x = GRU(h_size, return_sequences=True, kernel_regularizer=l2(weight_decay), unroll=True)(x)
x = BatchNormalization()(x)
x = Add()([x, skip_2])
x = Dropout(dropout_rate)(x)
skip_3 = x

x = GRU(h_size, return_sequences=True, kernel_regularizer=l2(weight_decay), unroll=True)(x)
x = BatchNormalization()(x)
x = Add()([x, skip_3])
x = Dropout(dropout_rate)(x)
skip_4 = x

x = GRU(h_size, return_sequences=False, kernel_regularizer=l2(weight_decay), unroll=True)(x)
x = BatchNormalization()(x)
x = Add()([x, skip_4[:, -1, :]])
x = Dropout(dropout_rate)(x)

outputs = Dense(n_characters, kernel_regularizer=l2(weight_decay))(x)
outputs = Activation("softmax")(outputs)

# Création du modèle
model = Model(inputs, outputs)
model.compile(loss="categorical_crossentropy", optimizer=Adam(learning_rate=initial_learning_rate), metrics=['accuracy'])


# Résumé du modèle
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 10, 72)]             0         []
#
#  gru_10 (GRU)                (None, 10, 128)              77568     ['input_3[0][0]']
#
#  batch_normalization_10 (Ba  (None, 10, 128)              512       ['gru_10[0][0]']
#  tchNormalization)
#
#  gru_11 (GRU)                (None, 10, 128)              99072     ['batch_normalization_10[0][0]
#                                                                     ']
#
#  batch_normalization_11 (Ba  (None, 10, 128)              512       ['gru_11[0][0]']
#  tchNormalization)
#
#  add_8 (Add)                 (None, 10, 128)              0         ['batch_normalization_11[0][0]
#                                                                     ',
#                                                                      'batch_normalization_10[0][0]
#                                                                     ']
#
#  dropout_8 (Dropout)         (None, 10, 128)              0         ['add_8[0][0]']
#
#  gru_12 (GRU)                (None, 10, 128)              99072     ['dropout_8[0][0]']
#
#  batch_normalization_12 (Ba  (None, 10, 128)              512       ['gru_12[0][0]']
#  tchNormalization)
#
#  add_9 (Add)                 (None, 10, 128)              0         ['batch_normalization_12[0][0]
#                                                                     ',
#                                                                      'dropout_8[0][0]']
#
#  dropout_9 (Dropout)         (None, 10, 128)              0         ['add_9[0][0]']
#
#  gru_13 (GRU)                (None, 10, 128)              99072     ['dropout_9[0][0]']
#
#  batch_normalization_13 (Ba  (None, 10, 128)              512       ['gru_13[0][0]']
#  tchNormalization)
#
#  add_10 (Add)                (None, 10, 128)              0         ['batch_normalization_13[0][0]
#                                                                     ',
#                                                                      'dropout_9[0][0]']
#
#  dropout_10 (Dropout)        (None, 10, 128)              0         ['add_10[0][0]']
#
#  gru_14 (GRU)                (None, 128)                  99072     ['dropout_10[0][0]']
#
#  batch_normalization_14 (Ba  (None, 128)                  512       ['gru_14[0][0]']
#  tchNormalization)
#
#  tf.__operators__.getitem_2  (None, 128)                  0         ['dropout_10[0][0]']
#   (SlicingOpLambda)
#
#  add_11 (Add)                (None, 128)                  0         ['batch_normalization_14[0][0]
#                                                                     ',
#                                                                      'tf.__operators__.getitem_2[0
#                                                                     ][0]']
#
#  dropout_11 (Dropout)        (None, 128)                  0         ['add_11[0][0]']
#
#  dense_2 (Dense)             (None, 72)                   9288      ['dropout_11[0][0]']
#
#  activation_2 (Activation)   (None, 72)                   0         ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 485704 (1.85 MB)
# Trainable params: 484424 (1.85 MB)
# Non-trainable params: 1280 (5.00 KB)
# __________________________________________________________________________________________________

# %%
# Callbacks
cosine_scheduler = CosineAnnealingScheduler(max_lr=0.005, min_lr=0.0001, total_epochs=num_epochs)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Initialisation du k-Fold Cross-Validation
kf = KFold(n_splits=k, shuffle=True, random_state=42)
fold_accuracies = []
history_dict = {'accuracy': [], 'val_accuracy': [], 'loss': [], 'val_loss': []}

for fold, (train_idx, val_idx) in enumerate(kf.split(X)):
    print(f"\n🔹 Fold {fold+1}/{k} : Entraînement en cours...\n")
    
    # Séparer les données pour ce fold
    X_train, X_val = X[train_idx], X[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    # Entraînement du modèle sur ce fold
    history = model.fit(X_train, y_train, batch_size=batch_size, epochs=num_epochs, validation_data=(X_val, y_val), callbacks=[cosine_scheduler])

    # Stocker l'historique
    for key in history.history.keys():
        history_dict[key].extend(history.history[key])

    # Évaluer la performance sur ce fold
    scores = model.evaluate(X_val, y_val, verbose=1)
    fold_accuracies.append(scores[1])

# Affichage des performances moyennes
print(f"\n✅ Performances moyennes sur les {k} folds : {np.mean(fold_accuracies) * 100:.2f}%")

# 🔹 Visualisation des courbes d'apprentissage
plt.figure(figsize=(12, 5))

# Accuracy
plt.subplot(1, 2, 1)
plt.plot(history_dict['accuracy'], label='accuracy')
plt.plot(history_dict['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.title('Evolution de l’Accuracy et de la Validation Accuracy')

# Loss
plt.subplot(1, 2, 2)
plt.plot(history_dict['loss'], label='loss')
plt.plot(history_dict['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.title('Evolution de la Loss et de la Validation Loss')

plt.show()
# Out:
# 🔹 Fold 1/10 : Entraînement en cours...
#
# Epoch 1: Learning rate is 0.003040
# Epoch 1/20
# 1164/1164 [==============================] - 101s 82ms/step - loss: 2.5432 - accuracy: 0.3166 - val_loss: 2.1161 - val_accuracy: 0.3925
# Epoch 2: Learning rate is 0.003022
# Epoch 2/20
# 1164/1164 [==============================] - 104s 90ms/step - loss: 2.1936 - accuracy: 0.3853 - val_loss: 2.0258 - val_accuracy: 0.4197
# Epoch 3: Learning rate is 0.002968
# Epoch 3/20
# 1164/1164 [==============================] - 97s 84ms/step - loss: 2.1213 - accuracy: 0.4098 - val_loss: 1.9706 - val_accuracy: 0.4458
# Epoch 4: Learning rate is 0.002880
# Epoch 4/20
# 1164/1164 [==============================] - 100s 86ms/step - loss: 2.0748 - accuracy: 0.4252 - val_loss: 1.9471 - val_accuracy: 0.4560
# Epoch 5: Learning rate is 0.002759
# Epoch 5/20
# 1164/1164 [==============================] - 102s 88ms/step - loss: 2.0412 - accuracy: 0.4364 - val_loss: 1.9191 - val_accuracy: 0.4646
# Epoch 6: Learning rate is 0.002609
# Epoch 6/20
# 1164/1164 [==============================] - 104s 89ms/step - loss: 2.0048 - accuracy: 0.4463 - val_loss: 1.9135 - val_accuracy: 0.4614
# Epoch 7: Learning rate is 0.002434
# Epoch 7/20
# 1164/1164 [==============================] - 111s 95ms/step - loss: 1.9682 - accuracy: 0.4555 - val_loss: 1.8591 - val_accuracy: 0.4791
# Epoch 8: Learning rate is 0.002237
# Epoch 8/20
# 1164/1164 [==============================] - 118s 101ms/step - loss: 1.9359 - accuracy: 0.4641 - val_loss: 1.8282 - val_accuracy: 0.4894
# Epoch 9: Learning rate is 0.002024
# Epoch 9/20
# 1164/1164 [==============================] - 108s 93ms/step - loss: 1.8970 - accuracy: 0.4735 - val_loss: 1.8136 - val_accuracy: 0.4925
# Epoch 10: Learning rate is 0.001800
# Epoch 10/20
# 1164/1164 [==============================] - 113s 97ms/step - loss: 1.8585 - accuracy: 0.4818 - val_loss: 1.7834 - val_accuracy: 0.5031
# Epoch 11: Learning rate is 0.001570
# Epoch 11/20
# 1164/1164 [==============================] - 97s 83ms/step - loss: 1.8206 - accuracy: 0.4899 - val_loss: 1.7468 - val_accuracy: 0.5116
# Epoch 12: Learning rate is 0.001340
# Epoch 12/20
# 1164/1164 [==============================] - 106s 91ms/step - loss: 1.7766 - accuracy: 0.5002 - val_loss: 1.7281 - val_accuracy: 0.5180
# Epoch 13: Learning rate is 0.001116
# Epoch 13/20
# 1164/1164 [==============================] - 97s 84ms/step - loss: 1.7375 - accuracy: 0.5076 - val_loss: 1.7022 - val_accuracy: 0.5234
# Epoch 14: Learning rate is 0.000903
# Epoch 14/20
# 1164/1164 [==============================] - 96s 83ms/step - loss: 1.6959 - accuracy: 0.5175 - val_loss: 1.6818 - val_accuracy: 0.5223
# Epoch 15: Learning rate is 0.000706
# Epoch 15/20
# 1164/1164 [==============================] - 98s 84ms/step - loss: 1.6598 - accuracy: 0.5265 - val_loss: 1.6579 - val_accuracy: 0.5317
# Epoch 16: Learning rate is 0.000531
# Epoch 16/20
# 1164/1164 [==============================] - 95s 82ms/step - loss: 1.6222 - accuracy: 0.5345 - val_loss: 1.6458 - val_accuracy: 0.5334
# Epoch 17: Learning rate is 0.000381
# Epoch 17/20
# 1164/1164 [==============================] - 95s 82ms/step - loss: 1.5881 - accuracy: 0.5438 - val_loss: 1.6321 - val_accuracy: 0.5366
# Epoch 18: Learning rate is 0.000260
# Epoch 18/20
# 1164/1164 [==============================] - 97s 83ms/step - loss: 1.5614 - accuracy: 0.5498 - val_loss: 1.6223 - val_accuracy: 0.5382
# Epoch 19: Learning rate is 0.000172
# Epoch 19/20
# 1164/1164 [==============================] - 98s 84ms/step - loss: 1.5398 - accuracy: 0.5541 - val_loss: 1.6152 - val_accuracy: 0.5402
# Epoch 20: Learning rate is 0.000118
# Epoch 20/20
# 1164/1164 [==============================] - 97s 83ms/step - loss: 1.5280 - accuracy: 0.5568 - val_loss: 1.6147 - val_accuracy: 0.5408
# 518/518 [==============================] - 5s 9ms/step - loss: 1.6147 - accuracy: 0.5408
#
# 🔹 Fold 2/10 : Entraînement en cours...
#
# Epoch 1: Learning rate is 0.003040
# Epoch 1/20
# 1164/1164 [==============================] - 94s 81ms/step - loss: 1.8913 - accuracy: 0.4731 - val_loss: 1.7686 - val_accuracy: 0.5082
# Epoch 2: Learning rate is 0.003022
# Epoch 2/20
# 1164/1164 [==============================] - 92s 79ms/step - loss: 1.9188 - accuracy: 0.4732 - val_loss: 1.8124 - val_accuracy: 0.4985
# Epoch 3: Learning rate is 0.002968
# Epoch 3/20
# 1164/1164 [==============================] - 93s 80ms/step - loss: 1.9232 - accuracy: 0.4733 - val_loss: 1.8184 - val_accuracy: 0.5005
# Epoch 4: Learning rate is 0.002880
# Epoch 4/20
# 1164/1164 [==============================] - 94s 81ms/step - loss: 1.9162 - accuracy: 0.4770 - val_loss: 1.8195 - val_accuracy: 0.4977
# Epoch 5: Learning rate is 0.002759
# Epoch 5/20
# 1164/1164 [==============================] - 94s 81ms/step - loss: 1.9039 - accuracy: 0.4797 - val_loss: 1.8020 - val_accuracy: 0.5073
# Epoch 6: Learning rate is 0.002609
# Epoch 6/20
# 1164/1164 [==============================] - 90s 77ms/step - loss: 1.8872 - accuracy: 0.4834 - val_loss: 1.7867 - val_accuracy: 0.5102
# Epoch 7: Learning rate is 0.002434
# Epoch 7/20
# 1164/1164 [==============================] - 93s 80ms/step - loss: 1.8577 - accuracy: 0.4899 - val_loss: 1.7750 - val_accuracy: 0.5115
# Epoch 8: Learning rate is 0.002237
# Epoch 8/20
# 1164/1164 [==============================] - 92s 79ms/step - loss: 1.8294 - accuracy: 0.4945 - val_loss: 1.7688 - val_accuracy: 0.5118
# Epoch 9: Learning rate is 0.002024
# Epoch 9/20
# 1164/1164 [==============================] - 93s 80ms/step - loss: 1.8002 - accuracy: 0.5022 - val_loss: 1.7471 - val_accuracy: 0.5122
# Epoch 10: Learning rate is 0.001800
# Epoch 10/20
# 1164/1164 [==============================] - 91s 78ms/step - loss: 1.7643 - accuracy: 0.5101 - val_loss: 1.7229 - val_accuracy: 0.5221
# Epoch 11: Learning rate is 0.001570
# Epoch 11/20
# 1164/1164 [==============================] - 92s 79ms/step - loss: 1.7285 - accuracy: 0.5180 - val_loss: 1.7009 - val_accuracy: 0.5275
# Epoch 12: Learning rate is 0.001340
# Epoch 12/20
# 1164/1164 [==============================] - 90s 78ms/step - loss: 1.6882 - accuracy: 0.5257 - val_loss: 1.6749 - val_accuracy: 0.5295
# Epoch 13: Learning rate is 0.001116
# Epoch 13/20
# 1164/1164 [==============================] - 92s 79ms/step - loss: 1.6501 - accuracy: 0.5341 - val_loss: 1.6585 - val_accuracy: 0.5347
# Epoch 14: Learning rate is 0.000903
# Epoch 14/20
# 1164/1164 [==============================] - 91s 78ms/step - loss: 1.6079 - accuracy: 0.5449 - val_loss: 1.6496 - val_accuracy: 0.5370
# Epoch 15: Learning rate is 0.000706
# Epoch 15/20
# 1164/1164 [==============================] - 90s 77ms/step - loss: 1.5738 - accuracy: 0.5521 - val_loss: 1.6312 - val_accuracy: 0.5416
# Epoch 16: Learning rate is 0.000531
# Epoch 16/20
# 1164/1164 [==============================] - 1335s 1s/step - loss: 1.5357 - accuracy: 0.5602 - val_loss: 1.6241 - val_accuracy: 0.5456
# Epoch 17: Learning rate is 0.000381
# Epoch 17/20
# 1164/1164 [==============================] - 74s 64ms/step - loss: 1.5044 - accuracy: 0.5675 - val_loss: 1.6145 - val_accuracy: 0.5440
# Epoch 18: Learning rate is 0.000260
# Epoch 18/20
# 1164/1164 [==============================] - 74s 64ms/step - loss: 1.4782 - accuracy: 0.5745 - val_loss: 1.6085 - val_accuracy: 0.5480
# Epoch 19: Learning rate is 0.000172
# Epoch 19/20
# 1164/1164 [==============================] - 75s 65ms/step - loss: 1.4559 - accuracy: 0.5798 - val_loss: 1.6079 - val_accuracy: 0.5462
# Epoch 20: Learning rate is 0.000118
# Epoch 20/20
# 1164/1164 [==============================] - 77s 66ms/step - loss: 1.4412 - accuracy: 0.5835 - val_loss: 1.6065 - val_accuracy: 0.5465
# 518/518 [==============================] - 3s 7ms/step - loss: 1.6065 - accuracy: 0.5465
#
# 🔹 Fold 3/10 : Entraînement en cours...
#
# Epoch 1: Learning rate is 0.003040
# Epoch 1/20
# 1164/1164 [==============================] - 74s 64ms/step - loss: 1.8280 - accuracy: 0.4946 - val_loss: 1.6959 - val_accuracy: 0.5332
# Epoch 2: Learning rate is 0.003022
# Epoch 2/20
# 1164/1164 [==============================] - 74s 63ms/step - loss: 1.8600 - accuracy: 0.4918 - val_loss: 1.7276 - val_accuracy: 0.5221
# Epoch 3: Learning rate is 0.002968
# Epoch 3/20
# 1164/1164 [==============================] - 71s 61ms/step - loss: 1.8646 - accuracy: 0.4898 - val_loss: 1.7442 - val_accuracy: 0.5245
# Epoch 4: Learning rate is 0.002880
# Epoch 4/20
# 1164/1164 [==============================] - 70s 60ms/step - loss: 1.8643 - accuracy: 0.4925 - val_loss: 1.7552 - val_accuracy: 0.5234
# Epoch 5: Learning rate is 0.002759
# Epoch 5/20
# 1164/1164 [==============================] - 66s 56ms/step - loss: 1.8491 - accuracy: 0.4960 - val_loss: 1.7336 - val_accuracy: 0.5228
# Epoch 6: Learning rate is 0.002609
# Epoch 6/20
# 1164/1164 [==============================] - 69s 59ms/step - loss: 1.8215 - accuracy: 0.5016 - val_loss: 1.7341 - val_accuracy: 0.5254
# Epoch 7: Learning rate is 0.002434
# Epoch 7/20
# 1164/1164 [==============================] - 69s 59ms/step - loss: 1.8059 - accuracy: 0.5047 - val_loss: 1.7088 - val_accuracy: 0.5314
# Epoch 8: Learning rate is 0.002237
# Epoch 8/20
# 1164/1164 [==============================] - 67s 57ms/step - loss: 1.7870 - accuracy: 0.5106 - val_loss: 1.6991 - val_accuracy: 0.5323
# Epoch 9: Learning rate is 0.002024
# Epoch 9/20
# 1164/1164 [==============================] - 64s 55ms/step - loss: 1.7511 - accuracy: 0.5172 - val_loss: 1.6854 - val_accuracy: 0.5341
# Epoch 10: Learning rate is 0.001800
# Epoch 10/20
# 1164/1164 [==============================] - 63s 54ms/step - loss: 1.7138 - accuracy: 0.5239 - val_loss: 1.6617 - val_accuracy: 0.5370
# Epoch 11: Learning rate is 0.001570
# Epoch 11/20
# 1164/1164 [==============================] - 62s 54ms/step - loss: 1.6745 - accuracy: 0.5340 - val_loss: 1.6380 - val_accuracy: 0.5433
# Epoch 12: Learning rate is 0.001340
# Epoch 12/20
# 1164/1164 [==============================] - 63s 54ms/step - loss: 1.6393 - accuracy: 0.5411 - val_loss: 1.6327 - val_accuracy: 0.5440
# Epoch 13: Learning rate is 0.001116
# Epoch 13/20
# 1164/1164 [==============================] - 63s 54ms/step - loss: 1.5950 - accuracy: 0.5495 - val_loss: 1.6120 - val_accuracy: 0.5512
# Epoch 14: Learning rate is 0.000903
# Epoch 14/20
# 1164/1164 [==============================] - 63s 54ms/step - loss: 1.5585 - accuracy: 0.5585 - val_loss: 1.5916 - val_accuracy: 0.5544
# Epoch 15: Learning rate is 0.000706
# Epoch 15/20
# 1164/1164 [==============================] - 65s 56ms/step - loss: 1.5206 - accuracy: 0.5681 - val_loss: 1.5824 - val_accuracy: 0.5575
# Epoch 16: Learning rate is 0.000531
# Epoch 16/20
# 1164/1164 [==============================] - 61s 52ms/step - loss: 1.4869 - accuracy: 0.5743 - val_loss: 1.5727 - val_accuracy: 0.5562
# Epoch 17: Learning rate is 0.000381
# Epoch 17/20
# 1164/1164 [==============================] - 60s 51ms/step - loss: 1.4551 - accuracy: 0.5821 - val_loss: 1.5671 - val_accuracy: 0.5604
# Epoch 18: Learning rate is 0.000260
# Epoch 18/20
# 1164/1164 [==============================] - 60s 52ms/step - loss: 1.4270 - accuracy: 0.5885 - val_loss: 1.5650 - val_accuracy: 0.5600
# Epoch 19: Learning rate is 0.000172
# Epoch 19/20
# 1164/1164 [==============================] - 66s 57ms/step - loss: 1.4063 - accuracy: 0.5956 - val_loss: 1.5612 - val_accuracy: 0.5609
# Epoch 20: Learning rate is 0.000118
# Epoch 20/20
# 1164/1164 [==============================] - 66s 57ms/step - loss: 1.3958 - accuracy: 0.5982 - val_loss: 1.5625 - val_accuracy: 0.5624
# 518/518 [==============================] - 4s 7ms/step - loss: 1.5625 - accuracy: 0.5624
#
# 🔹 Fold 4/10 : Entraînement en cours...
#
# Epoch 1: Learning rate is 0.003040
# Epoch 1/20
# 1164/1164 [==============================] - 66s 56ms/step - loss: 1.7900 - accuracy: 0.5064 - val_loss: 1.6761 - val_accuracy: 0.5383
# Epoch 2: Learning rate is 0.003022
# Epoch 2/20
# 1164/1164 [==============================] - 66s 57ms/step - loss: 1.8312 - accuracy: 0.5024 - val_loss: 1.7330 - val_accuracy: 0.5208
# Epoch 3: Learning rate is 0.002968
# Epoch 3/20
# 1164/1164 [==============================] - 67s 58ms/step - loss: 1.8324 - accuracy: 0.5038 - val_loss: 1.7176 - val_accuracy: 0.5302
# Epoch 4: Learning rate is 0.002880
# Epoch 4/20
# 1164/1164 [==============================] - 70s 60ms/step - loss: 1.8143 - accuracy: 0.5048 - val_loss: 1.7236 - val_accuracy: 0.5265
# Epoch 5: Learning rate is 0.002759
# Epoch 5/20
# 1164/1164 [==============================] - 67s 58ms/step - loss: 1.8061 - accuracy: 0.5069 - val_loss: 1.7186 - val_accuracy: 0.5259
# Epoch 6: Learning rate is 0.002609
# Epoch 6/20
# 1164/1164 [==============================] - 67s 57ms/step - loss: 1.7855 - accuracy: 0.5117 - val_loss: 1.7210 - val_accuracy: 0.5269
# Epoch 7: Learning rate is 0.002434
# Epoch 7/20
# 1164/1164 [==============================] - 69s 59ms/step - loss: 1.7579 - accuracy: 0.5168 - val_loss: 1.6825 - val_accuracy: 0.5346
# Epoch 8: Learning rate is 0.002237
# Epoch 8/20
# 1164/1164 [==============================] - 65s 55ms/step - loss: 1.7319 - accuracy: 0.5238 - val_loss: 1.6791 - val_accuracy: 0.5360
# Epoch 9: Learning rate is 0.002024
# Epoch 9/20
# 1164/1164 [==============================] - 63s 54ms/step - loss: 1.7056 - accuracy: 0.5306 - val_loss: 1.6643 - val_accuracy: 0.5396
# Epoch 10: Learning rate is 0.001800
# Epoch 10/20
# 1164/1164 [==============================] - 66s 57ms/step - loss: 1.6674 - accuracy: 0.5371 - val_loss: 1.6505 - val_accuracy: 0.5410
# Epoch 11: Learning rate is 0.001570
# Epoch 11/20
# 1164/1164 [==============================] - 63s 54ms/step - loss: 1.6345 - accuracy: 0.5433 - val_loss: 1.6304 - val_accuracy: 0.5462
# Epoch 12: Learning rate is 0.001340
# Epoch 12/20
# 1164/1164 [==============================] - 64s 55ms/step - loss: 1.5943 - accuracy: 0.5525 - val_loss: 1.6061 - val_accuracy: 0.5503
# Epoch 13: Learning rate is 0.001116
# Epoch 13/20
# 1164/1164 [==============================] - 65s 55ms/step - loss: 1.5558 - accuracy: 0.5627 - val_loss: 1.5941 - val_accuracy: 0.5540
# Epoch 14: Learning rate is 0.000903
# Epoch 14/20
# 1164/1164 [==============================] - 62s 54ms/step - loss: 1.5170 - accuracy: 0.5714 - val_loss: 1.5738 - val_accuracy: 0.5560
# Epoch 15: Learning rate is 0.000706
# Epoch 15/20
# 1164/1164 [==============================] - 64s 55ms/step - loss: 1.4774 - accuracy: 0.5784 - val_loss: 1.5731 - val_accuracy: 0.5570
# Epoch 16: Learning rate is 0.000531
# Epoch 16/20
# 1164/1164 [==============================] - 67s 58ms/step - loss: 1.4417 - accuracy: 0.5887 - val_loss: 1.5632 - val_accuracy: 0.5618
# Epoch 17: Learning rate is 0.000381
# Epoch 17/20
# 1164/1164 [==============================] - 68s 59ms/step - loss: 1.4134 - accuracy: 0.5947 - val_loss: 1.5603 - val_accuracy: 0.5625
# Epoch 18: Learning rate is 0.000260
# Epoch 18/20
# 1164/1164 [==============================] - 66s 57ms/step - loss: 1.3851 - accuracy: 0.6020 - val_loss: 1.5545 - val_accuracy: 0.5656
# Epoch 19: Learning rate is 0.000172
# Epoch 19/20
# 1164/1164 [==============================] - 66s 57ms/step - loss: 1.3628 - accuracy: 0.6082 - val_loss: 1.5562 - val_accuracy: 0.5606
# Epoch 20: Learning rate is 0.000118
# Epoch 20/20
# 1164/1164 [==============================] - 72s 62ms/step - loss: 1.3523 - accuracy: 0.6111 - val_loss: 1.5567 - val_accuracy: 0.5637
# 518/518 [==============================] - 3s 6ms/step - loss: 1.5567 - accuracy: 0.5637
#
# 🔹 Fold 5/10 : Entraînement en cours...
#
# Epoch 1: Learning rate is 0.003040
# Epoch 1/20
# 1164/1164 [==============================] - 67s 58ms/step - loss: 1.7513 - accuracy: 0.5174 - val_loss: 1.6363 - val_accuracy: 0.5456
# Epoch 2: Learning rate is 0.003022
# Epoch 2/20
# 1164/1164 [==============================] - 69s 59ms/step - loss: 1.7769 - accuracy: 0.5138 - val_loss: 1.6667 - val_accuracy: 0.5444
# Epoch 3: Learning rate is 0.002968
# Epoch 3/20
# 1164/1164 [==============================] - 68s 58ms/step - loss: 1.7934 - accuracy: 0.5126 - val_loss: 1.7192 - val_accuracy: 0.5243
# Epoch 4: Learning rate is 0.002880
# Epoch 4/20
# 1164/1164 [==============================] - 74s 64ms/step - loss: 1.7890 - accuracy: 0.5123 - val_loss: 1.7109 - val_accuracy: 0.5317
# Epoch 5: Learning rate is 0.002759
# Epoch 5/20
# 1164/1164 [==============================] - 75s 64ms/step - loss: 1.7756 - accuracy: 0.5147 - val_loss: 1.7126 - val_accuracy: 0.5341
# Epoch 6: Learning rate is 0.002609
# Epoch 6/20
# 1164/1164 [==============================] - 75s 64ms/step - loss: 1.7543 - accuracy: 0.5204 - val_loss: 1.6841 - val_accuracy: 0.5297
# Epoch 7: Learning rate is 0.002434
# Epoch 7/20
# 1164/1164 [==============================] - 73s 63ms/step - loss: 1.7299 - accuracy: 0.5254 - val_loss: 1.6837 - val_accuracy: 0.5308
# Epoch 8: Learning rate is 0.002237
# Epoch 8/20
# 1164/1164 [==============================] - 70s 60ms/step - loss: 1.7039 - accuracy: 0.5301 - val_loss: 1.6558 - val_accuracy: 0.5370
# Epoch 9: Learning rate is 0.002024
# Epoch 9/20
# 1164/1164 [==============================] - 70s 60ms/step - loss: 1.6745 - accuracy: 0.5370 - val_loss: 1.6371 - val_accuracy: 0.5461
# Epoch 10: Learning rate is 0.001800
# Epoch 10/20
# 1164/1164 [==============================] - 70s 60ms/step - loss: 1.6413 - accuracy: 0.5467 - val_loss: 1.6260 - val_accuracy: 0.5454
# Epoch 11: Learning rate is 0.001570
# Epoch 11/20
# 1164/1164 [==============================] - 70s 60ms/step - loss: 1.6076 - accuracy: 0.5514 - val_loss: 1.6109 - val_accuracy: 0.5499
# Epoch 12: Learning rate is 0.001340
# Epoch 12/20
# 1164/1164 [==============================] - 68s 59ms/step - loss: 1.5718 - accuracy: 0.5611 - val_loss: 1.5960 - val_accuracy: 0.5483
# Epoch 13: Learning rate is 0.001116
# Epoch 13/20
# 1164/1164 [==============================] - 69s 60ms/step - loss: 1.5271 - accuracy: 0.5703 - val_loss: 1.5739 - val_accuracy: 0.5553
# Epoch 14: Learning rate is 0.000903
# Epoch 14/20
# 1164/1164 [==============================] - 73s 63ms/step - loss: 1.4873 - accuracy: 0.5792 - val_loss: 1.5607 - val_accuracy: 0.5615
# Epoch 15: Learning rate is 0.000706
# Epoch 15/20
# 1164/1164 [==============================] - 74s 63ms/step - loss: 1.4464 - accuracy: 0.5888 - val_loss: 1.5523 - val_accuracy: 0.5588
# Epoch 16: Learning rate is 0.000531
# Epoch 16/20
# 1164/1164 [==============================] - 70s 60ms/step - loss: 1.4128 - accuracy: 0.5978 - val_loss: 1.5428 - val_accuracy: 0.5632
# Epoch 17: Learning rate is 0.000381
# Epoch 17/20
# 1164/1164 [==============================] - 68s 58ms/step - loss: 1.3833 - accuracy: 0.6056 - val_loss: 1.5426 - val_accuracy: 0.5630
# Epoch 18: Learning rate is 0.000260
# Epoch 18/20
# 1164/1164 [==============================] - 68s 59ms/step - loss: 1.3568 - accuracy: 0.6117 - val_loss: 1.5429 - val_accuracy: 0.5654
# Epoch 19: Learning rate is 0.000172
# Epoch 19/20
# 1164/1164 [==============================] - 69s 59ms/step - loss: 1.3334 - accuracy: 0.6159 - val_loss: 1.5427 - val_accuracy: 0.5668
# Epoch 20: Learning rate is 0.000118
# Epoch 20/20
# 1164/1164 [==============================] - 70s 60ms/step - loss: 1.3222 - accuracy: 0.6192 - val_loss: 1.5394 - val_accuracy: 0.5656
# 518/518 [==============================] - 4s 8ms/step - loss: 1.5394 - accuracy: 0.5656
#
# 🔹 Fold 6/10 : Entraînement en cours...
#
# Epoch 1: Learning rate is 0.003040
# Epoch 1/20
# 1164/1164 [==============================] - 71s 61ms/step - loss: 1.7176 - accuracy: 0.5235 - val_loss: 1.5863 - val_accuracy: 0.5600
# Epoch 2: Learning rate is 0.003022
# Epoch 2/20
# 1164/1164 [==============================] - 72s 62ms/step - loss: 1.7492 - accuracy: 0.5200 - val_loss: 1.6239 - val_accuracy: 0.5512
# Epoch 3: Learning rate is 0.002968
# Epoch 3/20
# 1164/1164 [==============================] - 75s 64ms/step - loss: 1.7533 - accuracy: 0.5175 - val_loss: 1.6504 - val_accuracy: 0.5421
# Epoch 4: Learning rate is 0.002880
# Epoch 4/20
# 1164/1164 [==============================] - 70s 60ms/step - loss: 1.7468 - accuracy: 0.5211 - val_loss: 1.6813 - val_accuracy: 0.5376
# Epoch 5: Learning rate is 0.002759
# Epoch 5/20
# 1164/1164 [==============================] - 72s 62ms/step - loss: 1.7421 - accuracy: 0.5219 - val_loss: 1.6524 - val_accuracy: 0.5410
# Epoch 6: Learning rate is 0.002609
# Epoch 6/20
# 1164/1164 [==============================] - 68s 59ms/step - loss: 1.7273 - accuracy: 0.5254 - val_loss: 1.6408 - val_accuracy: 0.5441
# Epoch 7: Learning rate is 0.002434
# Epoch 7/20
# 1164/1164 [==============================] - 67s 57ms/step - loss: 1.6930 - accuracy: 0.5331 - val_loss: 1.6392 - val_accuracy: 0.5461
# Epoch 8: Learning rate is 0.002237
# Epoch 8/20
# 1164/1164 [==============================] - 64s 55ms/step - loss: 1.6661 - accuracy: 0.5389 - val_loss: 1.6070 - val_accuracy: 0.5521
# Epoch 9: Learning rate is 0.002024
# Epoch 9/20
# 1164/1164 [==============================] - 65s 56ms/step - loss: 1.6371 - accuracy: 0.5442 - val_loss: 1.5966 - val_accuracy: 0.5532
# Epoch 10: Learning rate is 0.001800
# Epoch 10/20
# 1164/1164 [==============================] - 65s 56ms/step - loss: 1.6042 - accuracy: 0.5507 - val_loss: 1.5756 - val_accuracy: 0.5593
# Epoch 11: Learning rate is 0.001570
# Epoch 11/20
# 1164/1164 [==============================] - 66s 56ms/step - loss: 1.5696 - accuracy: 0.5587 - val_loss: 1.5733 - val_accuracy: 0.5575
# Epoch 12: Learning rate is 0.001340
# Epoch 12/20
# 1164/1164 [==============================] - 69s 59ms/step - loss: 1.5301 - accuracy: 0.5685 - val_loss: 1.5580 - val_accuracy: 0.5627
# Epoch 13: Learning rate is 0.001116
# Epoch 13/20
# 1164/1164 [==============================] - 67s 57ms/step - loss: 1.4934 - accuracy: 0.5764 - val_loss: 1.5411 - val_accuracy: 0.5645
# Epoch 14: Learning rate is 0.000903
# Epoch 14/20
# 1164/1164 [==============================] - 69s 59ms/step - loss: 1.4511 - accuracy: 0.5886 - val_loss: 1.5232 - val_accuracy: 0.5700
# Epoch 15: Learning rate is 0.000706
# Epoch 15/20
# 1164/1164 [==============================] - 69s 59ms/step - loss: 1.4152 - accuracy: 0.5969 - val_loss: 1.5181 - val_accuracy: 0.5693
# Epoch 16: Learning rate is 0.000531
# Epoch 16/20
# 1164/1164 [==============================] - 68s 58ms/step - loss: 1.3789 - accuracy: 0.6055 - val_loss: 1.5095 - val_accuracy: 0.5722
# Epoch 17: Learning rate is 0.000381
# Epoch 17/20
# 1164/1164 [==============================] - 68s 58ms/step - loss: 1.3490 - accuracy: 0.6128 - val_loss: 1.5148 - val_accuracy: 0.5731
# Epoch 18: Learning rate is 0.000260
# Epoch 18/20
# 1164/1164 [==============================] - 72s 62ms/step - loss: 1.3245 - accuracy: 0.6184 - val_loss: 1.5123 - val_accuracy: 0.5745
# Epoch 19: Learning rate is 0.000172
# Epoch 19/20
# 1164/1164 [==============================] - 68s 58ms/step - loss: 1.3052 - accuracy: 0.6242 - val_loss: 1.5088 - val_accuracy: 0.5743
# Epoch 20: Learning rate is 0.000118
# Epoch 20/20
# 1164/1164 [==============================] - 67s 58ms/step - loss: 1.2901 - accuracy: 0.6292 - val_loss: 1.5135 - val_accuracy: 0.5743
# 518/518 [==============================] - 3s 6ms/step - loss: 1.5135 - accuracy: 0.5743
#
# 🔹 Fold 7/10 : Entraînement en cours...
#
# Epoch 1: Learning rate is 0.003040
# Epoch 1/20
# 1164/1164 [==============================] - 67s 58ms/step - loss: 1.7019 - accuracy: 0.5254 - val_loss: 1.5448 - val_accuracy: 0.5734
# Epoch 2: Learning rate is 0.003022
# Epoch 2/20
# 1164/1164 [==============================] - 64s 55ms/step - loss: 1.7316 - accuracy: 0.5214 - val_loss: 1.5962 - val_accuracy: 0.5566
# Epoch 3: Learning rate is 0.002968
# Epoch 3/20
# 1164/1164 [==============================] - 64s 55ms/step - loss: 1.7405 - accuracy: 0.5232 - val_loss: 1.6024 - val_accuracy: 0.5584
# Epoch 4: Learning rate is 0.002880
# Epoch 4/20
# 1164/1164 [==============================] - 63s 54ms/step - loss: 1.7355 - accuracy: 0.5230 - val_loss: 1.6273 - val_accuracy: 0.5492
# Epoch 5: Learning rate is 0.002759
# Epoch 5/20
# 1164/1164 [==============================] - 64s 55ms/step - loss: 1.7109 - accuracy: 0.5285 - val_loss: 1.5960 - val_accuracy: 0.5607
# Epoch 6: Learning rate is 0.002609
# Epoch 6/20
# 1164/1164 [==============================] - 67s 57ms/step - loss: 1.7056 - accuracy: 0.5302 - val_loss: 1.6175 - val_accuracy: 0.5488
# Epoch 7: Learning rate is 0.002434
# Epoch 7/20
# 1164/1164 [==============================] - 67s 58ms/step - loss: 1.6790 - accuracy: 0.5360 - val_loss: 1.6041 - val_accuracy: 0.5508
# Epoch 8: Learning rate is 0.002237
# Epoch 8/20
# 1164/1164 [==============================] - 68s 58ms/step - loss: 1.6545 - accuracy: 0.5411 - val_loss: 1.5754 - val_accuracy: 0.5566
# Epoch 9: Learning rate is 0.002024
# Epoch 9/20
# 1164/1164 [==============================] - 68s 58ms/step - loss: 1.6261 - accuracy: 0.5486 - val_loss: 1.5578 - val_accuracy: 0.5627
# Epoch 10: Learning rate is 0.001800
# Epoch 10/20
# 1164/1164 [==============================] - 69s 59ms/step - loss: 1.5935 - accuracy: 0.5567 - val_loss: 1.5423 - val_accuracy: 0.5663
# Epoch 11: Learning rate is 0.001570
# Epoch 11/20
# 1164/1164 [==============================] - 67s 57ms/step - loss: 1.5549 - accuracy: 0.5648 - val_loss: 1.5298 - val_accuracy: 0.5683
# Epoch 12: Learning rate is 0.001340
# Epoch 12/20
# 1164/1164 [==============================] - 66s 57ms/step - loss: 1.5158 - accuracy: 0.5739 - val_loss: 1.5047 - val_accuracy: 0.5726
# Epoch 13: Learning rate is 0.001116
# Epoch 13/20
# 1164/1164 [==============================] - 68s 58ms/step - loss: 1.4783 - accuracy: 0.5826 - val_loss: 1.4971 - val_accuracy: 0.5738
# Epoch 14: Learning rate is 0.000903
# Epoch 14/20
# 1164/1164 [==============================] - 68s 59ms/step - loss: 1.4374 - accuracy: 0.5923 - val_loss: 1.4912 - val_accuracy: 0.5758
# Epoch 15: Learning rate is 0.000706
# Epoch 15/20
# 1164/1164 [==============================] - 69s 59ms/step - loss: 1.3981 - accuracy: 0.6030 - val_loss: 1.4773 - val_accuracy: 0.5801
# Epoch 16: Learning rate is 0.000531
# Epoch 16/20
# 1164/1164 [==============================] - 69s 59ms/step - loss: 1.3648 - accuracy: 0.6110 - val_loss: 1.4646 - val_accuracy: 0.5830
# Epoch 17: Learning rate is 0.000381
# Epoch 17/20
# 1164/1164 [==============================] - 71s 61ms/step - loss: 1.3333 - accuracy: 0.6177 - val_loss: 1.4631 - val_accuracy: 0.5837
# Epoch 18: Learning rate is 0.000260
# Epoch 18/20
# 1164/1164 [==============================] - 73s 63ms/step - loss: 1.3079 - accuracy: 0.6236 - val_loss: 1.4652 - val_accuracy: 0.5841
# Epoch 19: Learning rate is 0.000172
# Epoch 19/20
# 1164/1164 [==============================] - 69s 59ms/step - loss: 1.2895 - accuracy: 0.6290 - val_loss: 1.4612 - val_accuracy: 0.5852
# Epoch 20: Learning rate is 0.000118
# Epoch 20/20
# 1164/1164 [==============================] - 69s 59ms/step - loss: 1.2758 - accuracy: 0.6333 - val_loss: 1.4606 - val_accuracy: 0.5844
# 518/518 [==============================] - 3s 6ms/step - loss: 1.4606 - accuracy: 0.5844
#
# 🔹 Fold 8/10 : Entraînement en cours...
#
# Epoch 1: Learning rate is 0.003040
# Epoch 1/20
# 1164/1164 [==============================] - 71s 61ms/step - loss: 1.6900 - accuracy: 0.5319 - val_loss: 1.5653 - val_accuracy: 0.5666
# Epoch 2: Learning rate is 0.003022
# Epoch 2/20
# 1164/1164 [==============================] - 68s 59ms/step - loss: 1.7249 - accuracy: 0.5256 - val_loss: 1.6486 - val_accuracy: 0.5527
# Epoch 3: Learning rate is 0.002968
# Epoch 3/20
# 1164/1164 [==============================] - 70s 60ms/step - loss: 1.7457 - accuracy: 0.5250 - val_loss: 1.7059 - val_accuracy: 0.5350
# Epoch 4: Learning rate is 0.002880
# Epoch 4/20
# 1164/1164 [==============================] - 73s 62ms/step - loss: 1.7308 - accuracy: 0.5280 - val_loss: 1.6363 - val_accuracy: 0.5511
# Epoch 5: Learning rate is 0.002759
# Epoch 5/20
# 1164/1164 [==============================] - 69s 59ms/step - loss: 1.7139 - accuracy: 0.5301 - val_loss: 1.6250 - val_accuracy: 0.5519
# Epoch 6: Learning rate is 0.002609
# Epoch 6/20
# 1164/1164 [==============================] - 67s 57ms/step - loss: 1.6913 - accuracy: 0.5343 - val_loss: 1.6245 - val_accuracy: 0.5497
# Epoch 7: Learning rate is 0.002434
# Epoch 7/20
# 1164/1164 [==============================] - 64s 55ms/step - loss: 1.6624 - accuracy: 0.5399 - val_loss: 1.6175 - val_accuracy: 0.5512
# Epoch 8: Learning rate is 0.002237
# Epoch 8/20
# 1164/1164 [==============================] - 64s 55ms/step - loss: 1.6383 - accuracy: 0.5472 - val_loss: 1.5924 - val_accuracy: 0.5592
# Epoch 9: Learning rate is 0.002024
# Epoch 9/20
# 1164/1164 [==============================] - 64s 55ms/step - loss: 1.6088 - accuracy: 0.5511 - val_loss: 1.5779 - val_accuracy: 0.5601
# Epoch 10: Learning rate is 0.001800
# Epoch 10/20
# 1164/1164 [==============================] - 62s 53ms/step - loss: 1.5735 - accuracy: 0.5606 - val_loss: 1.5585 - val_accuracy: 0.5667
# Epoch 11: Learning rate is 0.001570
# Epoch 11/20
# 1164/1164 [==============================] - 62s 53ms/step - loss: 1.5398 - accuracy: 0.5689 - val_loss: 1.5406 - val_accuracy: 0.5663
# Epoch 12: Learning rate is 0.001340
# Epoch 12/20
# 1164/1164 [==============================] - 64s 55ms/step - loss: 1.5025 - accuracy: 0.5772 - val_loss: 1.5266 - val_accuracy: 0.5752
# Epoch 13: Learning rate is 0.001116
# Epoch 13/20
# 1164/1164 [==============================] - 65s 56ms/step - loss: 1.4616 - accuracy: 0.5877 - val_loss: 1.4990 - val_accuracy: 0.5772
# Epoch 14: Learning rate is 0.000903
# Epoch 14/20
# 1164/1164 [==============================] - 64s 55ms/step - loss: 1.4228 - accuracy: 0.5959 - val_loss: 1.4960 - val_accuracy: 0.5778
# Epoch 15: Learning rate is 0.000706
# Epoch 15/20
# 1164/1164 [==============================] - 65s 55ms/step - loss: 1.3859 - accuracy: 0.6052 - val_loss: 1.4805 - val_accuracy: 0.5809
# Epoch 16: Learning rate is 0.000531
# Epoch 16/20
# 1164/1164 [==============================] - 63s 54ms/step - loss: 1.3499 - accuracy: 0.6141 - val_loss: 1.4726 - val_accuracy: 0.5836
# Epoch 17: Learning rate is 0.000381
# Epoch 17/20
# 1164/1164 [==============================] - 63s 54ms/step - loss: 1.3181 - accuracy: 0.6218 - val_loss: 1.4721 - val_accuracy: 0.5851
# Epoch 18: Learning rate is 0.000260
# Epoch 18/20
# 1164/1164 [==============================] - 64s 55ms/step - loss: 1.2927 - accuracy: 0.6293 - val_loss: 1.4689 - val_accuracy: 0.5854
# Epoch 19: Learning rate is 0.000172
# Epoch 19/20
# 1164/1164 [==============================] - 63s 54ms/step - loss: 1.2745 - accuracy: 0.6330 - val_loss: 1.4683 - val_accuracy: 0.5876
# Epoch 20: Learning rate is 0.000118
# Epoch 20/20
# 1164/1164 [==============================] - 62s 53ms/step - loss: 1.2616 - accuracy: 0.6368 - val_loss: 1.4686 - val_accuracy: 0.5861
# 518/518 [==============================] - 3s 6ms/step - loss: 1.4686 - accuracy: 0.5861
#
# 🔹 Fold 9/10 : Entraînement en cours...
#
# Epoch 1: Learning rate is 0.003040
# Epoch 1/20
# 1164/1164 [==============================] - 68s 58ms/step - loss: 1.7078 - accuracy: 0.5322 - val_loss: 1.5704 - val_accuracy: 0.5664
# Epoch 2: Learning rate is 0.003022
# Epoch 2/20
# 1164/1164 [==============================] - 71s 61ms/step - loss: 1.7350 - accuracy: 0.5261 - val_loss: 1.5812 - val_accuracy: 0.5592
# Epoch 3: Learning rate is 0.002968
# Epoch 3/20
# 1164/1164 [==============================] - 67s 57ms/step - loss: 1.7288 - accuracy: 0.5268 - val_loss: 1.6050 - val_accuracy: 0.5570
# Epoch 4: Learning rate is 0.002880
# Epoch 4/20
# 1164/1164 [==============================] - 68s 59ms/step - loss: 1.7235 - accuracy: 0.5295 - val_loss: 1.6151 - val_accuracy: 0.5496
# Epoch 5: Learning rate is 0.002759
# Epoch 5/20
# 1164/1164 [==============================] - 70s 60ms/step - loss: 1.7032 - accuracy: 0.5340 - val_loss: 1.6094 - val_accuracy: 0.5514
# Epoch 6: Learning rate is 0.002609
# Epoch 6/20
# 1164/1164 [==============================] - 66s 56ms/step - loss: 1.6863 - accuracy: 0.5362 - val_loss: 1.5828 - val_accuracy: 0.5606
# Epoch 7: Learning rate is 0.002434
# Epoch 7/20
# 1164/1164 [==============================] - 64s 55ms/step - loss: 1.6652 - accuracy: 0.5411 - val_loss: 1.5814 - val_accuracy: 0.5602
# Epoch 8: Learning rate is 0.002237
# Epoch 8/20
# 1164/1164 [==============================] - 67s 57ms/step - loss: 1.6355 - accuracy: 0.5461 - val_loss: 1.5660 - val_accuracy: 0.5593
# Epoch 9: Learning rate is 0.002024
# Epoch 9/20
# 1164/1164 [==============================] - 66s 57ms/step - loss: 1.6032 - accuracy: 0.5529 - val_loss: 1.5528 - val_accuracy: 0.5637
# Epoch 10: Learning rate is 0.001800
# Epoch 10/20
# 1164/1164 [==============================] - 63s 54ms/step - loss: 1.5721 - accuracy: 0.5620 - val_loss: 1.5338 - val_accuracy: 0.5649
# Epoch 11: Learning rate is 0.001570
# Epoch 11/20
# 1164/1164 [==============================] - 66s 57ms/step - loss: 1.5336 - accuracy: 0.5702 - val_loss: 1.5090 - val_accuracy: 0.5699
# Epoch 12: Learning rate is 0.001340
# Epoch 12/20
# 1164/1164 [==============================] - 67s 58ms/step - loss: 1.4947 - accuracy: 0.5796 - val_loss: 1.4960 - val_accuracy: 0.5757
# Epoch 13: Learning rate is 0.001116
# Epoch 13/20
# 1164/1164 [==============================] - 65s 56ms/step - loss: 1.4538 - accuracy: 0.5891 - val_loss: 1.4751 - val_accuracy: 0.5790
# Epoch 14: Learning rate is 0.000903
# Epoch 14/20
# 1164/1164 [==============================] - 63s 54ms/step - loss: 1.4157 - accuracy: 0.5989 - val_loss: 1.4597 - val_accuracy: 0.5809
# Epoch 15: Learning rate is 0.000706
# Epoch 15/20
# 1164/1164 [==============================] - 65s 56ms/step - loss: 1.3769 - accuracy: 0.6083 - val_loss: 1.4554 - val_accuracy: 0.5828
# Epoch 16: Learning rate is 0.000531
# Epoch 16/20
# 1164/1164 [==============================] - 68s 59ms/step - loss: 1.3425 - accuracy: 0.6168 - val_loss: 1.4491 - val_accuracy: 0.5847
# Epoch 17: Learning rate is 0.000381
# Epoch 17/20
# 1164/1164 [==============================] - 68s 58ms/step - loss: 1.3128 - accuracy: 0.6236 - val_loss: 1.4442 - val_accuracy: 0.5892
# Epoch 18: Learning rate is 0.000260
# Epoch 18/20
# 1164/1164 [==============================] - 62s 54ms/step - loss: 1.2856 - accuracy: 0.6316 - val_loss: 1.4408 - val_accuracy: 0.5882
# Epoch 19: Learning rate is 0.000172
# Epoch 19/20
# 1164/1164 [==============================] - 63s 54ms/step - loss: 1.2653 - accuracy: 0.6358 - val_loss: 1.4418 - val_accuracy: 0.5882
# Epoch 20: Learning rate is 0.000118
# Epoch 20/20
# 1164/1164 [==============================] - 67s 57ms/step - loss: 1.2542 - accuracy: 0.6399 - val_loss: 1.4416 - val_accuracy: 0.5876
# 518/518 [==============================] - 3s 6ms/step - loss: 1.4416 - accuracy: 0.5876
#
# 🔹 Fold 10/10 : Entraînement en cours...
#
# Epoch 1: Learning rate is 0.003040
# Epoch 1/20
# 1164/1164 [==============================] - 66s 57ms/step - loss: 1.6750 - accuracy: 0.5348 - val_loss: 1.5536 - val_accuracy: 0.5665
# Epoch 2: Learning rate is 0.003022
# Epoch 2/20
# 1164/1164 [==============================] - 69s 59ms/step - loss: 1.6938 - accuracy: 0.5321 - val_loss: 1.5654 - val_accuracy: 0.5627
# Epoch 3: Learning rate is 0.002968
# Epoch 3/20
# 1164/1164 [==============================] - 72s 62ms/step - loss: 1.6968 - accuracy: 0.5326 - val_loss: 1.5685 - val_accuracy: 0.5654
# Epoch 4: Learning rate is 0.002880
# Epoch 4/20
# 1164/1164 [==============================] - 64s 55ms/step - loss: 1.6944 - accuracy: 0.5342 - val_loss: 1.5688 - val_accuracy: 0.5656
# Epoch 5: Learning rate is 0.002759
# Epoch 5/20
# 1164/1164 [==============================] - 63s 55ms/step - loss: 1.6920 - accuracy: 0.5338 - val_loss: 1.5733 - val_accuracy: 0.5644
# Epoch 6: Learning rate is 0.002609
# Epoch 6/20
# 1164/1164 [==============================] - 67s 57ms/step - loss: 1.6739 - accuracy: 0.5391 - val_loss: 1.5656 - val_accuracy: 0.5645
# Epoch 7: Learning rate is 0.002434
# Epoch 7/20
# 1164/1164 [==============================] - 67s 57ms/step - loss: 1.6529 - accuracy: 0.5437 - val_loss: 1.5716 - val_accuracy: 0.5612
# Epoch 8: Learning rate is 0.002237
# Epoch 8/20
# 1164/1164 [==============================] - 65s 56ms/step - loss: 1.6268 - accuracy: 0.5502 - val_loss: 1.5477 - val_accuracy: 0.5680
# Epoch 9: Learning rate is 0.002024
# Epoch 9/20
# 1164/1164 [==============================] - 66s 57ms/step - loss: 1.5958 - accuracy: 0.5572 - val_loss: 1.5337 - val_accuracy: 0.5699
# Epoch 10: Learning rate is 0.001800
# Epoch 10/20
# 1164/1164 [==============================] - 66s 57ms/step - loss: 1.5632 - accuracy: 0.5646 - val_loss: 1.5097 - val_accuracy: 0.5772
# Epoch 11: Learning rate is 0.001570
# Epoch 11/20
# 1164/1164 [==============================] - 70s 60ms/step - loss: 1.5239 - accuracy: 0.5733 - val_loss: 1.4833 - val_accuracy: 0.5819
# Epoch 12: Learning rate is 0.001340
# Epoch 12/20
# 1164/1164 [==============================] - 71s 61ms/step - loss: 1.4837 - accuracy: 0.5821 - val_loss: 1.4718 - val_accuracy: 0.5844
# Epoch 13: Learning rate is 0.001116
# Epoch 13/20
# 1164/1164 [==============================] - 69s 59ms/step - loss: 1.4463 - accuracy: 0.5913 - val_loss: 1.4565 - val_accuracy: 0.5894
# Epoch 14: Learning rate is 0.000903
# Epoch 14/20
# 1164/1164 [==============================] - 68s 58ms/step - loss: 1.4076 - accuracy: 0.6002 - val_loss: 1.4303 - val_accuracy: 0.5926
# Epoch 15: Learning rate is 0.000706
# Epoch 15/20
# 1164/1164 [==============================] - 68s 59ms/step - loss: 1.3722 - accuracy: 0.6096 - val_loss: 1.4283 - val_accuracy: 0.5949
# Epoch 16: Learning rate is 0.000531
# Epoch 16/20
# 1164/1164 [==============================] - 67s 58ms/step - loss: 1.3349 - accuracy: 0.6196 - val_loss: 1.4231 - val_accuracy: 0.5975
# Epoch 17: Learning rate is 0.000381
# Epoch 17/20
# 1164/1164 [==============================] - 66s 57ms/step - loss: 1.3027 - accuracy: 0.6280 - val_loss: 1.4159 - val_accuracy: 0.5984
# Epoch 18: Learning rate is 0.000260
# Epoch 18/20
# 1164/1164 [==============================] - 71s 61ms/step - loss: 1.2802 - accuracy: 0.6335 - val_loss: 1.4141 - val_accuracy: 0.5996
# Epoch 19: Learning rate is 0.000172
# Epoch 19/20
# 1164/1164 [==============================] - 71s 61ms/step - loss: 1.2598 - accuracy: 0.6390 - val_loss: 1.4121 - val_accuracy: 0.6011
# Epoch 20: Learning rate is 0.000118
# Epoch 20/20
# 1164/1164 [==============================] - 66s 57ms/step - loss: 1.2482 - accuracy: 0.6422 - val_loss: 1.4138 - val_accuracy: 0.6009
# 518/518 [==============================] - 3s 6ms/step - loss: 1.4138 - accuracy: 0.6009
#
# ✅ Performances moyennes sur les 10 folds : 57.12%

# %%
# 🔹 Ajout du Test-Time Scaling (TTS)
def apply_temperature_scaling(logits, temperature=2.0):
    """Applique le Temperature Scaling aux logits avant la softmax."""
    return logits / temperature

# Inférence avec TTS
def inference_with_tts(model, X_test, temperature=2.0):
    logits = model.predict(X_test)
    scaled_logits = apply_temperature_scaling(logits, temperature)
    probabilities = tf.nn.softmax(scaled_logits).numpy()
    return probabilities

# Test du modèle après TTS
scaled_predictions = inference_with_tts(model, X_val, temperature=2.0)

# 🔹 Affichage des résultats avant/après TTS
print(f"\n🔹 Exemple de prédiction avant TTS : {tf.nn.softmax(model.predict(X_val[:1]))}")
print(f"🔹 Exemple de prédiction après TTS : {scaled_predictions[:1]}")
# Out:
# 518/518 [==============================] - 4s 7ms/step
# 1/1 [==============================] - 0s 10ms/step
#
# 🔹 Exemple de prédiction avant TTS : [[0.01356517 0.01356517 0.01356517 0.01356517 0.01356517 0.01356517
#   0.01356517 0.01356517 0.01356517 0.01356517 0.01356517 0.01356517
#   0.01356517 0.01356517 0.01356517 0.01356517 0.01356517 0.01356517
#   0.01356517 0.01356517 0.01356517 0.01356517 0.01356517 0.01356517
#   0.01356517 0.01356517 0.01356517 0.01356517 0.01356517 0.01356517
#   0.01356517 0.01356517 0.01356527 0.01356517 0.01356517 0.01356517
#   0.01356517 0.01356517 0.01356517 0.01356517 0.01356517 0.01356517
#   0.01356517 0.01356517 0.01356517 0.01356517 0.01356517 0.01356517
#   0.01356518 0.03687266 0.01356517 0.01356517 0.01356517 0.01356551
#   0.01356517 0.01356517 0.01356517 0.01356517 0.01356517 0.01356517
#   0.01356517 0.01356517 0.01356517 0.01356517 0.01356517 0.01356517
#   0.01356517 0.01356517 0.01356517 0.01356517 0.01356517 0.01356517]]
# 🔹 Exemple de prédiction après TTS : [[0.01376487 0.01376487 0.01376487 0.01376487 0.01376487 0.01376487
#   0.01376487 0.01376487 0.01376487 0.01376487 0.01376487 0.01376487
#   0.01376487 0.01376487 0.01376487 0.01376487 0.01376487 0.01376487
#   0.01376487 0.01376487 0.01376487 0.01376487 0.01376487 0.01376487
#   0.01376487 0.01376487 0.01376487 0.01376487 0.01376487 0.01376487
#   0.01376487 0.01376487 0.01376492 0.01376487 0.01376487 0.01376487
#   0.01376487 0.01376487 0.01376487 0.01376487 0.01376487 0.01376487
#   0.01376487 0.01376487 0.01376487 0.01376487 0.01376487 0.01376487
#   0.01376488 0.02269404 0.01376487 0.01376487 0.01376487 0.01376505
#   0.01376487 0.01376487 0.01376487 0.01376487 0.01376487 0.01376487
#   0.01376487 0.01376487 0.01376487 0.01376487 0.01376487 0.01376487
#   0.01376487 0.01376487 0.01376487 0.01376487 0.01376487 0.01376487]]

# %%
def plot_layer_parameters(model):
    for layer in model.layers:
        if isinstance(layer, (SimpleRNN, GRU, Dense)):
            # Récupérer tous les poids de la couche
            layer_weights = layer.get_weights()
            
            # Vérifier le nombre de valeurs retournées
            if len(layer_weights) >= 2:
                weights = layer_weights[0]  # Les poids principaux
                biases = layer_weights[1]   # Les biais
                
                print(f"Layer: {layer.name}")
                print(f"Weights shape: {weights.shape}, Biases shape: {biases.shape}")
                
                # Calcul de la variance des poids par neurone
                if isinstance(layer, GRU):
                    # Pour GRU, les poids sont structurés différemment
                    weight_variances = np.var(weights, axis=0)
                    # Nous prenons la variance pour chaque unité
                    weight_variances = np.var(weights, axis=0)
                    num_units = layer.units
                    plt.figure(figsize=(10, 5))
                    plt.bar(range(num_units), weight_variances[:num_units])
                    plt.title(f'Variance of Weights per Neuron in Layer {layer.name}')
                    plt.xlabel('Neuron Index')
                    plt.ylabel('Variance')
                    plt.show()
                else:
                    weight_variances = np.var(weights, axis=0)
                    plt.figure(figsize=(10, 5))
                    plt.bar(range(len(weight_variances)), weight_variances)
                    plt.title(f'Variance of Weights per Neuron in Layer {layer.name}')
                    plt.xlabel('Neuron Index')
                    plt.ylabel('Variance')
                    plt.show()
                
                # Vérifier la forme des biais avant de les tracer
                if len(biases.shape) == 1:  # Si les biais sont unidimensionnels
                    plt.figure(figsize=(10, 5))
                    plt.bar(range(len(biases)), biases)
                    plt.title(f'Biases in Layer {layer.name}')
                    plt.xlabel('Neuron Index')
                    plt.ylabel('Bias Value')
                    plt.show()
                else:
                    print(f"Biases in layer {layer.name} have a complex shape and cannot be plotted directly.")
            else:
                print(f"Layer {layer.name} does not have standard weights and biases.")
        else:
            print(f"Layer {layer.name} is not a SimpleRNN, GRU, or Dense layer.")

# Appel de la fonction
plot_layer_parameters(model)
# Out:
# Layer input_3 is not a SimpleRNN, GRU, or Dense layer.
# Layer: gru_10
# Weights shape: (72, 384), Biases shape: (128, 384)
# Biases in layer gru_10 have a complex shape and cannot be plotted directly.
# Layer batch_normalization_10 is not a SimpleRNN, GRU, or Dense layer.
# Layer: gru_11
# Weights shape: (128, 384), Biases shape: (128, 384)
# Biases in layer gru_11 have a complex shape and cannot be plotted directly.
# Layer batch_normalization_11 is not a SimpleRNN, GRU, or Dense layer.
# Layer add_8 is not a SimpleRNN, GRU, or Dense layer.
# Layer dropout_8 is not a SimpleRNN, GRU, or Dense layer.
# Layer: gru_12
# Weights shape: (128, 384), Biases shape: (128, 384)
# Biases in layer gru_12 have a complex shape and cannot be plotted directly.
# Layer batch_normalization_12 is not a SimpleRNN, GRU, or Dense layer.
# Layer add_9 is not a SimpleRNN, GRU, or Dense layer.
# Layer dropout_9 is not a SimpleRNN, GRU, or Dense layer.
# Layer: gru_13
# Weights shape: (128, 384), Biases shape: (128, 384)
# Biases in layer gru_13 have a complex shape and cannot be plotted directly.
# Layer batch_normalization_13 is not a SimpleRNN, GRU, or Dense layer.
# Layer add_10 is not a SimpleRNN, GRU, or Dense layer.
# Layer dropout_10 is not a SimpleRNN, GRU, or Dense layer.
# Layer: gru_14
# Weights shape: (128, 384), Biases shape: (128, 384)
# Biases in layer gru_14 have a complex shape and cannot be plotted directly.
# Layer batch_normalization_14 is not a SimpleRNN, GRU, or Dense layer.
# Layer tf.__operators__.getitem_2 is not a SimpleRNN, GRU, or Dense layer.
# Layer add_11 is not a SimpleRNN, GRU, or Dense layer.
# Layer dropout_11 is not a SimpleRNN, GRU, or Dense layer.
# Layer: dense_2
# Weights shape: (128, 72), Biases shape: (72,)
# Layer activation_2 is not a SimpleRNN, GRU, or Dense layer.

# %%
# 🔹 Évaluation finale
scores_train = model.evaluate(X_train, y_train, verbose=1)
scores_test = model.evaluate(X_val, y_val, verbose=1)

print(f"📊 Performances finales (apprentissage, {model.metrics_names[1]}) = {scores_train[1]*100:.2f}%")
print(f"📊 Performances finales (validation, {model.metrics_names[1]}) = {scores_test[1]*100:.2f}%")
# Out:
# 4655/4655 [==============================] - 32s 7ms/step - loss: 1.0742 - accuracy: 0.6919
# 518/518 [==============================] - 4s 7ms/step - loss: 1.4138 - accuracy: 0.6009
# 📊 Performances finales (apprentissage, accuracy) = 69.19%
# 📊 Performances finales (validation, accuracy) = 60.09%

# %%
#model_name = f"SimpleRNN_{h_size}_{num_epochs}epochs"
#model.save(model_name)

# %%
#from tensorflow.keras.models import load_model
#model = load_model(model_name)
#model.compile(loss='categorical_crossentropy', optimizer='RMSprop', metrics=['accuracy'])
#model.summary()

# %%
idx = 10
# index2char permet de repasser de l'encodage one-hot au caractère du dictionnaire
initial_characters = [index2char[np.argmax(c)] for c in X_train[idx]]
initial_text = "".join(initial_characters)
print(f"La séquence n°{idx} est : '{initial_text}'")
# Out:
# La séquence n°10 est : 't gutenber'

# %%
test_sequence = np.zeros((1, SEQLEN, n_characters), dtype=bool)
test_sequence[0] = X_train[idx]
prediction = model.predict(test_sequence)
print(prediction)
# Out:
# 1/1 [==============================] - 0s 12ms/step
# [[4.78637673e-07 2.89919804e-08 9.44818357e-09 1.98320332e-12
#   6.34216735e-10 2.50652832e-10 1.86493239e-07 9.14544496e-10
#   2.87573521e-09 1.11237339e-10 5.77220263e-08 1.87353377e-09
#   2.94703256e-07 3.26622018e-09 2.11396101e-09 6.40769215e-10
#   6.23383940e-08 5.99528747e-08 9.29806721e-09 8.16830834e-08
#   3.76309828e-09 2.85721484e-07 1.45919090e-08 2.36122055e-08
#   1.21165716e-10 1.15976153e-08 8.80027784e-09 3.64079850e-10
#   7.82506504e-10 8.51662574e-10 4.28041130e-10 1.08705945e-06
#   2.10005510e-06 4.62681413e-07 4.07453683e-07 2.66029787e-07
#   9.99985099e-01 1.80836057e-08 4.83934803e-09 5.80011017e-09
#   5.99083614e-06 1.93646112e-08 1.16311103e-08 6.81152471e-07
#   6.12871176e-08 1.25365629e-09 3.31151249e-08 5.89795227e-11
#   9.85898474e-09 4.26622336e-07 6.55431875e-10 2.68214222e-07
#   1.53833398e-07 2.96677172e-09 4.48428716e-09 7.38408374e-08
#   1.47336032e-10 6.98080482e-13 4.38108527e-09 8.54594839e-10
#   1.30035141e-06 3.00162534e-11 4.26200797e-10 7.71562675e-11
#   4.51149701e-10 5.37161482e-10 9.76964551e-11 5.48431873e-12
#   1.04506915e-11 2.54257421e-10 8.74745415e-11 1.72025039e-14]]

# %%
def sample(probabilities, temperature=1.0):
    probabilities = np.asarray(probabilities).astype('float64')
    # Modifie la distribution selon la valeur de la température
    probabilities = pow(probabilities, 1.0/temperature)
    probabilities /= np.sum(probabilities)
    # Tire des variables aléatoires selon la distribution multinomiale transformée
    random_values = np.random.multinomial(1, probabilities, 1)
    # Renvoie le symbole échantillonné
    return np.argmax(random_values)

# %%
# Longueur du texte à générer (en caractères)
text_length = 200
# Température
temperature = 0.5

generated_text = initial_text
network_input = test_sequence

for i in range(text_length):
    last_characters = generated_text[-SEQLEN:]
    
    # Préparer l'entrée pour la prédiction
    test_sequence = np.zeros((1, SEQLEN, n_characters), dtype=bool)
    for t, char in enumerate(last_characters):
        test_sequence[0, t, char2index[char]] = 1
    
    # Prédiction du modèle
    prediction = model.predict(test_sequence, verbose=0)
    
    # Échantillonner un caractère à partir de la distribution de probabilité
    predicted_char_index = sample(prediction[0], temperature)
    predicted_char = index2char[predicted_char_index]
    
    # Ajouter le caractère prédit au texte généré
    generated_text += predicted_char

print("Texte généré:")
print(generated_text)
# Out:
# Texte généré:
# t gutenberg-tm electronic works in the united states works in any project gutenberg-tm electronic works in any halmon on le jour de notre souvenir de la forme de la vie et du bour et de ces couleurs des deux po

# %%
# Fonction de softmax
def softmax(logits):
    exp_logits = np.exp(logits - np.max(logits))  # Stabilité numérique
    return exp_logits / np.sum(exp_logits)

# Fonction de sampling avec température et top-k
def sample(preds, temperature=1.0, top_k=5):
    preds = np.asarray(preds).astype("float64")
    preds = np.log(preds + 1e-10) / temperature  # Appliquer température
    preds = softmax(preds)

    # Optionnel: Limiter aux k meilleures probabilités
    if top_k > 0:
        top_k_indices = np.argsort(preds)[-top_k:]
        preds_top_k = preds[top_k_indices]
        preds_top_k /= np.sum(preds_top_k)  # Renormaliser
        return np.random.choice(top_k_indices, p=preds_top_k)
    
    return np.random.choice(len(preds), p=preds)

# 3. Génération de texte avec self-probing et calcul de l'entropie
def generate_text_with_entropy(model, initial_text, text_length=200, temperature=0.7, num_samples=10, top_k=5):
    generated_texts = []
    entropies = []
    
    for _ in range(num_samples):
        generated_text = initial_text
        network_input = np.zeros((1, SEQLEN, n_characters), dtype=bool)
        for t, char in enumerate(initial_text):
            if char in char2index:
                network_input[0, t, char2index[char]] = 1
        
        for i in range(text_length):
            prediction = model.predict(network_input, verbose=0)[0]

            # Appliquer le sampling
            predicted_char_index = sample(prediction, temperature, top_k)
            predicted_char = index2char[predicted_char_index]
            
            # Ajouter le caractère prédit au texte généré
            generated_text += predicted_char
            
            # Mettre à jour l'entrée du réseau (Recréer plutôt que décaler)
            network_input = np.zeros((1, SEQLEN, n_characters), dtype=bool)
            last_chars = generated_text[-SEQLEN:]
            for t, char in enumerate(last_chars):
                if char in char2index:
                    network_input[0, t, char2index[char]] = 1
        
        generated_texts.append(generated_text)
        
        # Calcul de l'entropie sur la dernière sortie
        logits = model.predict(network_input, verbose=0)[0]
        probs = softmax(logits)  # Softmax appliqué correctement
        entropies.append(entropy(probs))
    
    return generated_texts, entropies

# Génération de texte avec self-probing et calcul de l'entropie
generated_texts, entropies = generate_text_with_entropy(model, initial_text, text_length=200, temperature=0.7, num_samples=10, top_k=5)

for i, (text, ent) in enumerate(zip(generated_texts, entropies)):
    print(f"Sample {i+1}:")
    print(text)
    print(f"Entropy: {ent:.4f}")
    print("-" * 80)
# Out:
# Sample 1:
# t gutenberg-tm electronic works in the united states without pouttre paster et charmé de son prime incorturelent d'un peintre un soleil couter des maisreaue et dont le souvenir dans un tapis de ton amour naisse
# Entropy: 4.2700
# --------------------------------------------------------------------------------
# Sample 2:
# t gutenberg-tm license all le pence les ressemins et le vent des démons pour qui de la fraise en voyage le long des pelus, et tes pousses les seins du carps et les cieux de sa forme conside la gronde dit, mon c
# Entropy: 4.2679
# --------------------------------------------------------------------------------
# Sample 3:
# t gutenberg-tm electronic works in any project gutenberg literary archive foundation and distributing a repose de l'insolenle de l'arme les morts, s'avanse et le vin de loin des sommeils de son francherre son l
# Entropy: 4.2751
# --------------------------------------------------------------------------------
# Sample 4:
# t gutenberg literary archive foundation as cris amour dans le fond dans les coeurs dévisse le parfum de la triste roi le corps se provodant son beau qui danse des pleurs du parfum de l'homme en ressec la pendul
# Entropy: 4.2653
# --------------------------------------------------------------------------------
# Sample 5:
# t gutenberg-tm electronic work agute et nous minuiles en best ange, le souvenir sont repentraient des morts, les parfums, parfumé, et l'archer de la probet de martique ouvert l'amour, dans le coeur des filles d
# Entropy: 4.2726
# --------------------------------------------------------------------------------
# Sample 6:
# t gutenberg literary archive foundation project gutenberg-tm work, and passion et de s'ancoeur, dans, son coeur sur les caresses d'autres, la creuse et sur le coeur des plaisirs du coupent sur l'ennemi computan
# Entropy: 4.2654
# --------------------------------------------------------------------------------
# Sample 7:
# t gutenberg-tm work and partir tes sommeils marchanes de tes deins des brises de la creuse, le vent du mal per au serment, avec la cris me mensect infris et dans le couvercle en dansant de charmante, caveau de
# Entropy: 4.2758
# --------------------------------------------------------------------------------
# Sample 8:
# t gutenberg-tm works contain froide par ses palais, resprisante et sont dans tous tes déchirant la gloire de tourmente, et qui se mémoire à mon rougaite et prince, en morte, sa forte ce chat ne doux ton chamme
# Entropy: 4.2756
# --------------------------------------------------------------------------------
# Sample 9:
# t gutenberg literary archive foundation as proffides infinis, et la pleine de flammes, de ces gouffres avec des chardes, des souvenirs de ton ange sont diginé sont ronds plaintes sur les princes ses chages les
# Entropy: 4.2762
# --------------------------------------------------------------------------------
# Sample 10:
# t gutenberg-tm electronic work is provided this work in any work or any particular st te donnerai que son fantôme douleur et le plus plus charmants, par une franche au cour de la mer au parfum ne paraissons, mo
# Entropy: 4.2671
# --------------------------------------------------------------------------------

# %%
entropies
# Out:
# [4.26998,
#  4.267866,
#  4.2751007,
#  4.265259,
#  4.272597,
#  4.2653513,
#  4.2758355,
#  4.275633,
#  4.2761726,
#  4.267088]

# %% [markdown]
# ## Correction othographique

# %%
import random

def introduce_typos(text, error_rate=0.1):
    """Ajoute des erreurs aléatoires dans un texte avec un certain taux de bruit."""
    chars = list(text)
    for i in range(len(chars)):
        if random.random() < error_rate:
            chars[i] = random.choice("abcdefghijklmnopqrstuvwxyz")  # Substitue une lettre
    return "".join(chars)

# %%
def correct_text(model, noisy_text, char2index, index2char, SEQLEN, n_characters, temperature=0.5):
    """ Corrige un texte bruité en générant une version corrigée avec le modèle """
    corrected_text = noisy_text[:SEQLEN]  # Conserver le début intact
    for i in range(len(noisy_text) - SEQLEN):
        last_characters = corrected_text[-SEQLEN:]

        # Préparer l'entrée pour la prédiction
        test_sequence = np.zeros((1, SEQLEN, n_characters), dtype=bool)
        for t, char in enumerate(last_characters):
            if char in char2index:
                test_sequence[0, t, char2index[char]] = 1

        # Prédiction du modèle
        prediction = model.predict(test_sequence, verbose=0)

        # Échantillonner un caractère à partir de la distribution de probabilité
        predicted_char_index = sample(prediction[0], temperature)
        predicted_char = index2char[predicted_char_index]

        # Ajouter le caractère prédit au texte corrigé
        corrected_text += predicted_char

    return corrected_text

# %%
# Exemple
original_text = "Bonjour, comment allez-vous aujourd'hui ?"
noisy_text = introduce_typos(original_text, error_rate=0.15)

corrected_text = correct_text(model, noisy_text, char2index, index2char, SEQLEN, n_characters)

print(f"Texte original : {original_text}")
print("Texte bruité   :", noisy_text)
print("Texte corrigé  :", corrected_text)
# Out:
# Texte original : Bonjour, comment allez-vous aujourd'hui ?
# Texte bruité   : Bomjour, commentuallez-foue asjourdyhui ?
# Texte corrigé  : Bomjour, comme un douce vaincuté de l'ang

# %%
import Levenshtein

def character_error_rate(reference, hypothesis):
    """Calcule le CER (Character Error Rate)"""
    return Levenshtein.distance(reference, hypothesis) / len(reference)

def word_error_rate(reference, hypothesis):
    """Calcule le WER (Word Error Rate)"""
    ref_words = reference.split()
    hyp_words = hypothesis.split()
    return Levenshtein.distance(" ".join(ref_words), " ".join(hyp_words)) / len(ref_words)

cer = character_error_rate(original_text, corrected_text)
wer = word_error_rate(original_text, corrected_text)

print(f"CER : {cer:.2%}")
print(f"WER : {wer:.2%}")
# Out:
# CER : 63.41%
# WER : 520.00%

# %% [markdown]
# 	•	CER (63.41%) : Près de 2 caractères sur 3 sont incorrects, le modèle altère fortement le texte.
# 	•	WER (580%) : Les erreurs sont 5 fois plus nombreuses que les mots, le texte devient incompréhensible.
#
# 📉 Problèmes possibles :
# 	1.	Sur-apprentissage ou mauvais entraînement (données bruitées, mauvaise segmentation).
# 	2.	Échantillonnage trop aléatoire (température trop élevée).
# 	3.	Erreur dans la conversion texte ↔ one-hot.
#
# Solutions :
#  Réduire la température lors de la génération.
#  Améliorer l’entraînement (régularisation, dropout, meilleure segmentation).
#  Tester avec des phrases simples avant des corrections plus complexes.
