# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("wordnet")
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
import tensorflow as tf
from tensorflow.keras.layers import Input, Embedding, SimpleRNN, Dense, GRU, Activation, LSTM, Bidirectional, MultiHeadAttention, Concatenate, Dropout, BatchNormalization
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers.legacy import Adam, RMSprop
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.optimizers.schedules import CosineDecay
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import os
import re
#from gensim.models import Word2Vec
import plotly.express as px
import keras.backend as K
from keras.regularizers import l2
from keras.callbacks import EarlyStopping
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/yassineseidou/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/yassineseidou/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/yassineseidou/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Lire le fichier texte et ajouter toutes les lignes dans une liste
with open("fleurs_mal.txt", 'r' , encoding = 'utf8') as f:
    lines = f.readlines()

df = ''.join(lines)

tokens = word_tokenize(df.lower())
print("There are :",len(tokens), "words in the document")
print("There are :",len(set(tokens)), "unique words in the document")
# Out:
# There are : 32562 words in the document
# There are : 6975 unique words in the document

# %%
for idx, line in enumerate(lines):
    if "Charles Baudelaire avait un ami" in line:
        first_line = idx
    if "End of the Project Gutenberg EBook of Les Fleurs du Mal, by Charles Baudelaire" in line:
        last_line = idx

# %% [markdown]
# ## Analyse Exploratoire

# %%
plt.figure(figsize=(20,20))
wc = WordCloud(max_words=100,
               height=800,
               width=1600,
               ).generate(df)
plt.imshow(wc, interpolation="bilinear")

# visualize the distribution of number of words in a text

fig = px.histogram(x = [len(x) for x in tokens], nbins = 100)
fig.show()

# %%
stop_words = stopwords.words('french')
#stop_words.extend(['from', 'subject', 're', 'edu', 'use', 'le', 'la', 'du', 'des', 'un', 'une', 'a'])
stop_words
# Out:
# ['au',
#  'aux',
#  'avec',
#  'ce',
#  'ces',
#  'dans',
#  'de',
#  'des',
#  'du',
#  'elle',
#  'en',
#  'et',
#  'eux',
#  'il',
#  'ils',
#  'je',
#  'la',
#  'le',
#  'les',
#  'leur',
#  'lui',
#  'ma',
#  'mais',
#  'me',
#  'même',
#  'mes',
#  'moi',
#  'mon',
#  'ne',
#  'nos',
#  'notre',
#  'nous',
#  'on',
#  'ou',
#  'par',
#  'pas',
#  'pour',
#  'qu',
#  'que',
#  'qui',
#  'sa',
#  'se',
#  'ses',
#  'son',
#  'sur',
#  'ta',
#  'te',
#  'tes',
#  'toi',
#  'ton',
#  'tu',
#  'un',
#  'une',
#  'vos',
#  'votre',
#  'vous',
#  'c',
#  'd',
#  'j',
#  'l',
#  'à',
#  'm',
#  'n',
#  's',
#  't',
#  'y',
#  'été',
#  'étée',
#  'étées',
#  'étés',
#  'étant',
#  'étante',
#  'étants',
#  'étantes',
#  'suis',
#  'es',
#  'est',
#  'sommes',
#  'êtes',
#  'sont',
#  'serai',
#  'seras',
#  'sera',
#  'serons',
#  'serez',
#  'seront',
#  'serais',
#  'serait',
#  'serions',
#  'seriez',
#  'seraient',
#  'étais',
#  'était',
#  'étions',
#  'étiez',
#  'étaient',
#  'fus',
#  'fut',
#  'fûmes',
#  'fûtes',
#  'furent',
#  'sois',
#  'soit',
#  'soyons',
#  'soyez',
#  'soient',
#  'fusse',
#  'fusses',
#  'fût',
#  'fussions',
#  'fussiez',
#  'fussent',
#  'ayant',
#  'ayante',
#  'ayantes',
#  'ayants',
#  'eu',
#  'eue',
#  'eues',
#  'eus',
#  'ai',
#  'as',
#  'avons',
#  'avez',
#  'ont',
#  'aurai',
#  'auras',
#  'aura',
#  'aurons',
#  'aurez',
#  'auront',
#  'aurais',
#  'aurait',
#  'aurions',
#  'auriez',
#  'auraient',
#  'avais',
#  'avait',
#  'avions',
#  'aviez',
#  'avaient',
#  'eut',
#  'eûmes',
#  'eûtes',
#  'eurent',
#  'aie',
#  'aies',
#  'ait',
#  'ayons',
#  'ayez',
#  'aient',
#  'eusse',
#  'eusses',
#  'eût',
#  'eussions',
#  'eussiez',
#  'eussent']

# %%
len(stop_words)
# Out:
# 157

# %% [markdown]
# ## Traitement du texte

# %%
# Initialisation du lemmatizer
lemmatizer = WordNetLemmatizer()

def preprocess_text(text, stop_words):
    """
    Nettoie et prétraite le texte :
    - Met en minuscule
    - Supprime les caractères spéciaux
    - Tokenize
    - Retire les stopwords
    - Lematise les mots restants
    """
    # Convertir en minuscule
    text = text.lower()
    
    # Supprimer les caractères spéciaux (on garde les mots uniquement)
    text = re.sub(r"[^\w\s]", "", text)
    
    # Tokenization
    tokens = word_tokenize(text)
    
    # Retirer les stopwords
    tokens = [word for word in tokens if word not in stop_words]
    
    # Lemmatisation
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens]
    
    return lemmatized_tokens

# %%
# Appliquer la fonction au corpus
preprocessed_tokens = preprocess_text(df, stop_words)

# Vérifier les résultats
print("Exemple de tokens prétraités :", preprocessed_tokens[:50])
print("Nombre total de mots après prétraitement :", len(preprocessed_tokens))
print("Nombre de mots uniques après prétraitement :", len(set(preprocessed_tokens)))
# Out:
# Exemple de tokens prétraités : ['the', 'project', 'gutenberg', 'ebook', 'of', 'fleurs', 'mal', 'by', 'charles', 'baudelaire', 'this', 'ebook', 'is', 'for', 'the', 'use', 'of', 'anyone', 'anywhere', 'at', 'no', 'cost', 'and', 'with', 'almost', 'no', 'restriction', 'whatsoever', 'you', 'may', 'copy', 'it', 'give', 'it', 'away', 'or', 'reuse', 'it', 'under', 'the', 'term', 'of', 'the', 'project', 'gutenberg', 'license', 'included', 'with', 'this', 'ebook']
# Nombre total de mots après prétraitement : 18235
# Nombre de mots uniques après prétraitement : 6654

# %%
plt.figure(figsize=(20,20))
wc = WordCloud(max_words=100,
               height=800,
               width=1600,
               ).generate(" ".join(preprocessed_tokens))
plt.imshow(wc, interpolation="bilinear")

# Distribution de la longueur des textes après prétraitement
fig = px.histogram(x=[len(x) for x in preprocessed_tokens], nbins=100)
fig.show()

# %%
for idx, line in enumerate(preprocessed_tokens):
    if "Charles Baudelaire" in line:
        first_line = idx
    if "End of the Project" in line:
        last_line = idx

# %%
lines = preprocessed_tokens[first_line:last_line]
lines = [l.lower().strip().replace('_', '') for l in lines if len(l) > 1]
text = " ".join(lines)

# %%
characters = sorted(set(text))
n_characters = len(characters)

# %%
# SEQLEN représente la taille de la séquence de lettres à passer en entrée
SEQLEN = 10
step = 1
input_characters, labels = [], []
# On parcourt le corpus de texte avec une fenêtre glissante
for i in range(0, len(text) - SEQLEN, step):
    input_characters.append(text[i:i + SEQLEN])
    labels.append(text[i + SEQLEN])

print(f"Il y a {len(input_characters)} séquences de {SEQLEN} caractères dans le corpus d'entraînement.")
# Out:
# Il y a 34848 séquences de 10 caractères dans le corpus d'entraînement.

# %%
# Encodage caractère -> indice du dictionaire
char2index = dict((c, i) for i, c in enumerate(characters))
# Encodage de l'indice vers le caractère (utilisé pour décoder les prédictions du modèle)
index2char = dict((i, c) for i, c in enumerate(characters)) # mapping index -> char in dictionary

# %%
# Initialisation des tenseurs
X = np.zeros((len(input_characters), SEQLEN, n_characters), dtype=bool)
y = np.zeros((len(input_characters), n_characters), dtype=bool)

# Remplissage des tenseurs X et y
for idx_seq, sequence in enumerate(input_characters):
    for idx_char, char in enumerate(sequence):
        # Encode chaque caractère dans une représentation one-hot
        X[idx_seq, idx_char, char2index[char]] = 1
    # Encode le caractère cible correspondant
    y[idx_seq, char2index[labels[idx_seq]]] = 1

print("Encodage terminé.")
print(f"X shape: {X.shape}, y shape: {y.shape}")
# Out:
# Encodage terminé.
# X shape: (34848, 10, 47), y shape: (34848, 47)

# %%
from sklearn.model_selection import train_test_split

# 80% des données en apprentissage, 20% en validation
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.9, random_state=42)

# %% [markdown]
# ### Model

# %%
from tensorflow.keras.callbacks import Callback

# Cosine Annealing Scheduler
class CosineAnnealingScheduler(Callback):
    def __init__(self, max_lr, min_lr, total_epochs):
        super(CosineAnnealingScheduler, self).__init__()
        self.max_lr = max_lr
        self.min_lr = min_lr
        self.total_epochs = total_epochs

    def on_epoch_begin(self, epoch, logs=None):
        # Calculer le learning rate pour l'epoch courant
        cosine_lr = self.min_lr + 0.3 * (self.max_lr - self.min_lr) * (
            1 + np.cos(np.pi * epoch / self.total_epochs)
        )
        # Mettre à jour le learning rate de l'optimiseur
        self.model.optimizer.lr.assign(cosine_lr)
        print(f"Epoch {epoch+1}: Learning rate is {cosine_lr:.6f}")

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.optimizers.schedules import CosineDecay
from tensorflow.keras.regularizers import l2

class LinearRecurrentUnit(layers.Layer):
    def __init__(self, input_size, hidden_size, output_size, kernel_regularizer=None):
        super(LinearRecurrentUnit, self).__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.kernel_regularizer = kernel_regularizer
        
        # Define the linear recurrence matrices (A, B, C, D)
        self.A = self.add_weight(
            "A", 
            shape=(hidden_size, hidden_size),
            initializer="random_normal",
            regularizer=kernel_regularizer,
            trainable=True
        )
        self.B = self.add_weight(
            "B", 
            shape=(input_size, hidden_size),
            initializer="random_normal",
            regularizer=kernel_regularizer,
            trainable=True
        )
        self.C = self.add_weight(
            "C", 
            shape=(hidden_size, output_size),
            initializer="random_normal",
            regularizer=kernel_regularizer,
            trainable=True
        )
        self.D = self.add_weight(
            "D", 
            shape=(input_size, output_size),
            initializer="random_normal",
            regularizer=kernel_regularizer,
            trainable=True
        )
        
        # Layer normalization
        self.norm = layers.LayerNormalization()

    def call(self, inputs, training=False):
        # Get the batch size dynamically from inputs
        batch_size = tf.shape(inputs)[0]
        seq_len = inputs.shape[1]
        
        # Initialize hidden state with zeros, using batch_size dynamically
        h = tf.zeros((batch_size, self.hidden_size), dtype=tf.float32)
        outputs = []
        
        for t in range(seq_len):
            u = inputs[:, t, :]
            h = tf.matmul(h, self.A) + tf.matmul(u, self.B)
            h = self.norm(h)
            # Compute output at each time step
            y_t = tf.matmul(h, self.C) + tf.matmul(u, self.D)
            outputs.append(y_t)
        
        # Stack outputs to form a sequence
        return tf.stack(outputs, axis=1)

# Model parameters
h_size = 128
dropout_rate = 0.1
n_characters = 47
output_size = 47  # Should match your target dimension
SEQLEN = 10
num_epochs = 100
batch_size = 64
weight_decay = 0.0001

# Learning rate setup
initial_learning_rate = 0.001
decay_steps = num_epochs * (1000 // batch_size)
cosine_decay = CosineDecay(initial_learning_rate, decay_steps)

# Optimizer
optim = Adam(initial_learning_rate)

# Build the model
model = Sequential()
model.add(LinearRecurrentUnit(
    input_size=n_characters,
    hidden_size=h_size,
    output_size=h_size,
    kernel_regularizer=l2(weight_decay)
))
BatchNormalization()

model.add(LinearRecurrentUnit(
    input_size=h_size,
    hidden_size=h_size,
    output_size=h_size,
    kernel_regularizer=l2(weight_decay)
))
BatchNormalization()

model.add(LinearRecurrentUnit(
    input_size=h_size,
    hidden_size=h_size,
    output_size=h_size,
    kernel_regularizer=l2(weight_decay)
))
BatchNormalization()

model.add(LinearRecurrentUnit(
    input_size=h_size,
    hidden_size=h_size,
    output_size=h_size,
    kernel_regularizer=l2(weight_decay)
))
BatchNormalization()

model.add(layers.Dropout(dropout_rate))

# Take the last time step's output for classification
model.add(layers.Lambda(lambda x: x[:, -1, :]))
model.add(layers.Dense(n_characters))
model.add(layers.Activation("softmax"))

# Compile the model
model.compile(
    loss="categorical_crossentropy",
    optimizer=optim,
    metrics=['accuracy']
)

# Set input shape for the model (batch_size, seq_len, input_size)
model.build(input_shape=(None, SEQLEN, n_characters))

model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  linear_recurrent_unit_17 (  (None, 10, 128)           45056
#  LinearRecurrentUnit)
#
#  linear_recurrent_unit_18 (  (None, 10, 128)           65792
#  LinearRecurrentUnit)
#
#  linear_recurrent_unit_19 (  (None, 10, 128)           65792
#  LinearRecurrentUnit)
#
#  linear_recurrent_unit_20 (  (None, 10, 128)           65792
#  LinearRecurrentUnit)
#
#  dropout_3 (Dropout)         (None, 10, 128)           0
#
#  lambda_3 (Lambda)           (None, 128)               0
#
#  dense_3 (Dense)             (None, 47)                6063
#
#  activation_3 (Activation)   (None, 47)                0
#
# =================================================================
# Total params: 248495 (970.68 KB)
# Trainable params: 248495 (970.68 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#model.fit(X_train, y_train, batch_size=batch_size, epochs=num_epochs)
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import entropy

cosine_scheduler = CosineAnnealingScheduler(max_lr=0.001, min_lr=0.0001, total_epochs=num_epochs)
# Définition de l'EarlyStopping pour arrêter l'entraînement en cas de surapprentissage
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Visualisation de l'évolution de l'accuracy et de la val_accuracy
history = model.fit(X_train, y_train, batch_size=batch_size, epochs=num_epochs, validation_data=(X_test, y_test), callbacks=[cosine_scheduler])

plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.title('Evolution of Accuracy and Validation Accuracy')
plt.show()
# Out:
# Epoch 1: Learning rate is 0.000640
# Epoch 1/100
# 491/491 [==============================] - 25s 42ms/step - loss: 2.8375 - accuracy: 0.1916 - val_loss: 2.6025 - val_accuracy: 0.2433
# Epoch 2: Learning rate is 0.000640
# Epoch 2/100
# 491/491 [==============================] - 22s 45ms/step - loss: 2.4943 - accuracy: 0.2672 - val_loss: 2.4645 - val_accuracy: 0.2746
# Epoch 3: Learning rate is 0.000639
# Epoch 3/100
# 491/491 [==============================] - 21s 44ms/step - loss: 2.4051 - accuracy: 0.2881 - val_loss: 2.4491 - val_accuracy: 0.2872
# Epoch 4: Learning rate is 0.000639
# Epoch 4/100
# 491/491 [==============================] - 23s 47ms/step - loss: 2.3591 - accuracy: 0.2939 - val_loss: 2.3530 - val_accuracy: 0.3010
# Epoch 5: Learning rate is 0.000638
# Epoch 5/100
# 491/491 [==============================] - 20s 42ms/step - loss: 2.3303 - accuracy: 0.3022 - val_loss: 2.3508 - val_accuracy: 0.2924
# Epoch 6: Learning rate is 0.000637
# Epoch 6/100
# 491/491 [==============================] - 21s 42ms/step - loss: 2.3005 - accuracy: 0.3074 - val_loss: 2.2700 - val_accuracy: 0.3050
# Epoch 7: Learning rate is 0.000635
# Epoch 7/100
# 491/491 [==============================] - 21s 42ms/step - loss: 2.2668 - accuracy: 0.3150 - val_loss: 2.2871 - val_accuracy: 0.2990
# Epoch 8: Learning rate is 0.000633
# Epoch 8/100
# 491/491 [==============================] - 21s 43ms/step - loss: 2.2519 - accuracy: 0.3218 - val_loss: 2.2419 - val_accuracy: 0.3294
# Epoch 9: Learning rate is 0.000632
# Epoch 9/100
# 491/491 [==============================] - 21s 43ms/step - loss: 2.2299 - accuracy: 0.3270 - val_loss: 2.2257 - val_accuracy: 0.3248
# Epoch 10: Learning rate is 0.000629
# Epoch 10/100
# 491/491 [==============================] - 22s 44ms/step - loss: 2.2058 - accuracy: 0.3362 - val_loss: 2.2693 - val_accuracy: 0.3214
# Epoch 11: Learning rate is 0.000627
# Epoch 11/100
# 491/491 [==============================] - 21s 42ms/step - loss: 2.1887 - accuracy: 0.3408 - val_loss: 2.2437 - val_accuracy: 0.3329
# Epoch 12: Learning rate is 0.000624
# Epoch 12/100
# 491/491 [==============================] - 21s 42ms/step - loss: 2.1777 - accuracy: 0.3438 - val_loss: 2.2198 - val_accuracy: 0.3392
# Epoch 13: Learning rate is 0.000621
# Epoch 13/100
# 491/491 [==============================] - 21s 42ms/step - loss: 2.1668 - accuracy: 0.3438 - val_loss: 2.2234 - val_accuracy: 0.3352
# Epoch 14: Learning rate is 0.000618
# Epoch 14/100
# 491/491 [==============================] - 21s 43ms/step - loss: 2.1527 - accuracy: 0.3507 - val_loss: 2.1723 - val_accuracy: 0.3492
# Epoch 15: Learning rate is 0.000614
# Epoch 15/100
# 491/491 [==============================] - 21s 42ms/step - loss: 2.1430 - accuracy: 0.3495 - val_loss: 2.1605 - val_accuracy: 0.3506
# Epoch 16: Learning rate is 0.000611
# Epoch 16/100
# 491/491 [==============================] - 21s 42ms/step - loss: 2.1262 - accuracy: 0.3552 - val_loss: 2.1924 - val_accuracy: 0.3449
# Epoch 17: Learning rate is 0.000607
# Epoch 17/100
# 491/491 [==============================] - 21s 42ms/step - loss: 2.1233 - accuracy: 0.3566 - val_loss: 2.1536 - val_accuracy: 0.3360
# Epoch 18: Learning rate is 0.000602
# Epoch 18/100
# 491/491 [==============================] - 21s 42ms/step - loss: 2.1097 - accuracy: 0.3591 - val_loss: 2.1628 - val_accuracy: 0.3512
# Epoch 19: Learning rate is 0.000598
# Epoch 19/100
# 491/491 [==============================] - 21s 43ms/step - loss: 2.1066 - accuracy: 0.3600 - val_loss: 2.1803 - val_accuracy: 0.3440
# Epoch 20: Learning rate is 0.000593
# Epoch 20/100
# 491/491 [==============================] - 21s 44ms/step - loss: 2.0945 - accuracy: 0.3654 - val_loss: 2.1531 - val_accuracy: 0.3575
# Epoch 21: Learning rate is 0.000588
# Epoch 21/100
# 491/491 [==============================] - 28s 56ms/step - loss: 2.0825 - accuracy: 0.3704 - val_loss: 2.1410 - val_accuracy: 0.3590
# Epoch 22: Learning rate is 0.000583
# Epoch 22/100
# 491/491 [==============================] - 25s 52ms/step - loss: 2.0772 - accuracy: 0.3709 - val_loss: 2.1441 - val_accuracy: 0.3595
# Epoch 23: Learning rate is 0.000578
# Epoch 23/100
# 491/491 [==============================] - 23s 46ms/step - loss: 2.0661 - accuracy: 0.3744 - val_loss: 2.1390 - val_accuracy: 0.3529
# Epoch 24: Learning rate is 0.000573
# Epoch 24/100
# 491/491 [==============================] - 21s 43ms/step - loss: 2.0602 - accuracy: 0.3757 - val_loss: 2.1473 - val_accuracy: 0.3567
# Epoch 25: Learning rate is 0.000567
# Epoch 25/100
# 491/491 [==============================] - 26s 53ms/step - loss: 2.0543 - accuracy: 0.3770 - val_loss: 2.1148 - val_accuracy: 0.3659
# Epoch 26: Learning rate is 0.000561
# Epoch 26/100
# 491/491 [==============================] - 23s 47ms/step - loss: 2.0451 - accuracy: 0.3813 - val_loss: 2.1299 - val_accuracy: 0.3615
# Epoch 27: Learning rate is 0.000555
# Epoch 27/100
# 491/491 [==============================] - 22s 44ms/step - loss: 2.0352 - accuracy: 0.3830 - val_loss: 2.1221 - val_accuracy: 0.3681
# Epoch 28: Learning rate is 0.000549
# Epoch 28/100
# 491/491 [==============================] - 24s 48ms/step - loss: 2.0318 - accuracy: 0.3797 - val_loss: 2.1192 - val_accuracy: 0.3681
# Epoch 29: Learning rate is 0.000542
# Epoch 29/100
# 491/491 [==============================] - 23s 46ms/step - loss: 2.0216 - accuracy: 0.3896 - val_loss: 2.0995 - val_accuracy: 0.3802
# Epoch 30: Learning rate is 0.000535
# Epoch 30/100
# 491/491 [==============================] - 21s 44ms/step - loss: 2.0112 - accuracy: 0.3895 - val_loss: 2.0941 - val_accuracy: 0.3765
# Epoch 31: Learning rate is 0.000529
# Epoch 31/100
# 491/491 [==============================] - 21s 43ms/step - loss: 2.0075 - accuracy: 0.3922 - val_loss: 2.1389 - val_accuracy: 0.3676
# Epoch 32: Learning rate is 0.000522
# Epoch 32/100
# 491/491 [==============================] - 21s 42ms/step - loss: 2.0029 - accuracy: 0.3899 - val_loss: 2.1090 - val_accuracy: 0.3768
# Epoch 33: Learning rate is 0.000515
# Epoch 33/100
# 491/491 [==============================] - 21s 42ms/step - loss: 1.9954 - accuracy: 0.3911 - val_loss: 2.1350 - val_accuracy: 0.3618
# Epoch 34: Learning rate is 0.000507
# Epoch 34/100
# 491/491 [==============================] - 21s 43ms/step - loss: 1.9925 - accuracy: 0.3966 - val_loss: 2.0766 - val_accuracy: 0.3747
# Epoch 35: Learning rate is 0.000500
# Epoch 35/100
# 491/491 [==============================] - 21s 42ms/step - loss: 1.9827 - accuracy: 0.3978 - val_loss: 2.1104 - val_accuracy: 0.3707
# Epoch 36: Learning rate is 0.000493
# Epoch 36/100
# 491/491 [==============================] - 21s 43ms/step - loss: 1.9808 - accuracy: 0.3975 - val_loss: 2.0985 - val_accuracy: 0.3773
# Epoch 37: Learning rate is 0.000485
# Epoch 37/100
# 491/491 [==============================] - 21s 43ms/step - loss: 1.9679 - accuracy: 0.4055 - val_loss: 2.1029 - val_accuracy: 0.3664
# Epoch 38: Learning rate is 0.000477
# Epoch 38/100
# 491/491 [==============================] - 21s 43ms/step - loss: 1.9718 - accuracy: 0.4005 - val_loss: 2.0956 - val_accuracy: 0.3845
# Epoch 39: Learning rate is 0.000469
# Epoch 39/100
# 491/491 [==============================] - 20s 41ms/step - loss: 1.9598 - accuracy: 0.4035 - val_loss: 2.0877 - val_accuracy: 0.3802
# Epoch 40: Learning rate is 0.000461
# Epoch 40/100
# 491/491 [==============================] - 21s 42ms/step - loss: 1.9547 - accuracy: 0.4068 - val_loss: 2.1112 - val_accuracy: 0.3676
# Epoch 41: Learning rate is 0.000453
# Epoch 41/100
# 491/491 [==============================] - 21s 42ms/step - loss: 1.9462 - accuracy: 0.4101 - val_loss: 2.0602 - val_accuracy: 0.3989
# Epoch 42: Learning rate is 0.000445
# Epoch 42/100
# 491/491 [==============================] - 21s 42ms/step - loss: 1.9363 - accuracy: 0.4101 - val_loss: 2.0860 - val_accuracy: 0.3894
# Epoch 43: Learning rate is 0.000437
# Epoch 43/100
# 491/491 [==============================] - 21s 42ms/step - loss: 1.9373 - accuracy: 0.4116 - val_loss: 2.0672 - val_accuracy: 0.3759
# Epoch 44: Learning rate is 0.000429
# Epoch 44/100
# 491/491 [==============================] - 21s 42ms/step - loss: 1.9258 - accuracy: 0.4144 - val_loss: 2.0825 - val_accuracy: 0.3808
# Epoch 45: Learning rate is 0.000421
# Epoch 45/100
# 491/491 [==============================] - 22s 45ms/step - loss: 1.9197 - accuracy: 0.4164 - val_loss: 2.0796 - val_accuracy: 0.3882
# Epoch 46: Learning rate is 0.000412
# Epoch 46/100
# 491/491 [==============================] - 21s 42ms/step - loss: 1.9172 - accuracy: 0.4157 - val_loss: 2.0761 - val_accuracy: 0.3802
# Epoch 47: Learning rate is 0.000404
# Epoch 47/100
# 491/491 [==============================] - 20s 42ms/step - loss: 1.9064 - accuracy: 0.4206 - val_loss: 2.0552 - val_accuracy: 0.3994
# Epoch 48: Learning rate is 0.000395
# Epoch 48/100
# 491/491 [==============================] - 21s 42ms/step - loss: 1.9006 - accuracy: 0.4240 - val_loss: 2.0705 - val_accuracy: 0.3894
# Epoch 49: Learning rate is 0.000387
# Epoch 49/100
# 491/491 [==============================] - 21s 43ms/step - loss: 1.8950 - accuracy: 0.4226 - val_loss: 2.0868 - val_accuracy: 0.3902
# Epoch 50: Learning rate is 0.000378
# Epoch 50/100
# 491/491 [==============================] - 21s 43ms/step - loss: 1.8865 - accuracy: 0.4265 - val_loss: 2.0727 - val_accuracy: 0.3859
# Epoch 51: Learning rate is 0.000370
# Epoch 51/100
# 491/491 [==============================] - 21s 43ms/step - loss: 1.8833 - accuracy: 0.4263 - val_loss: 2.0631 - val_accuracy: 0.3966
# Epoch 52: Learning rate is 0.000362
# Epoch 52/100
# 491/491 [==============================] - 20s 42ms/step - loss: 1.8732 - accuracy: 0.4271 - val_loss: 2.0580 - val_accuracy: 0.3879
# Epoch 53: Learning rate is 0.000353
# Epoch 53/100
# 491/491 [==============================] - 21s 43ms/step - loss: 1.8702 - accuracy: 0.4310 - val_loss: 2.0921 - val_accuracy: 0.3874
# Epoch 54: Learning rate is 0.000345
# Epoch 54/100
# 491/491 [==============================] - 21s 42ms/step - loss: 1.8636 - accuracy: 0.4334 - val_loss: 2.1331 - val_accuracy: 0.3805
# Epoch 55: Learning rate is 0.000336
# Epoch 55/100
# 491/491 [==============================] - 21s 42ms/step - loss: 1.8580 - accuracy: 0.4341 - val_loss: 2.0899 - val_accuracy: 0.3940
# Epoch 56: Learning rate is 0.000328
# Epoch 56/100
# 491/491 [==============================] - 21s 43ms/step - loss: 1.8559 - accuracy: 0.4327 - val_loss: 2.0595 - val_accuracy: 0.3983
# Epoch 57: Learning rate is 0.000319
# Epoch 57/100
# 491/491 [==============================] - 20s 42ms/step - loss: 1.8476 - accuracy: 0.4361 - val_loss: 2.0659 - val_accuracy: 0.3925
# Epoch 58: Learning rate is 0.000311
# Epoch 58/100
# 491/491 [==============================] - 20s 41ms/step - loss: 1.8379 - accuracy: 0.4390 - val_loss: 2.0730 - val_accuracy: 0.3971
# Epoch 59: Learning rate is 0.000303
# Epoch 59/100
# 491/491 [==============================] - 20s 42ms/step - loss: 1.8337 - accuracy: 0.4390 - val_loss: 2.0768 - val_accuracy: 0.3923
# Epoch 60: Learning rate is 0.000295
# Epoch 60/100
# 491/491 [==============================] - 21s 42ms/step - loss: 1.8259 - accuracy: 0.4436 - val_loss: 2.0642 - val_accuracy: 0.3888
# Epoch 61: Learning rate is 0.000287
# Epoch 61/100
# 491/491 [==============================] - 21s 42ms/step - loss: 1.8190 - accuracy: 0.4442 - val_loss: 2.0637 - val_accuracy: 0.3991
# Epoch 62: Learning rate is 0.000279
# Epoch 62/100
# 491/491 [==============================] - 21s 42ms/step - loss: 1.8141 - accuracy: 0.4454 - val_loss: 2.0828 - val_accuracy: 0.3928
# Epoch 63: Learning rate is 0.000271
# Epoch 63/100
# 491/491 [==============================] - 21s 43ms/step - loss: 1.8117 - accuracy: 0.4482 - val_loss: 2.0881 - val_accuracy: 0.3931
# Epoch 64: Learning rate is 0.000263
# Epoch 64/100
# 491/491 [==============================] - 21s 42ms/step - loss: 1.8056 - accuracy: 0.4488 - val_loss: 2.0836 - val_accuracy: 0.3871
# Epoch 65: Learning rate is 0.000255
# Epoch 65/100
# 491/491 [==============================] - 21s 42ms/step - loss: 1.7918 - accuracy: 0.4530 - val_loss: 2.0797 - val_accuracy: 0.3917
# Epoch 66: Learning rate is 0.000247
# Epoch 66/100
# 491/491 [==============================] - 21s 42ms/step - loss: 1.7895 - accuracy: 0.4562 - val_loss: 2.0767 - val_accuracy: 0.3934
# Epoch 67: Learning rate is 0.000240
# Epoch 67/100
# 491/491 [==============================] - 29s 60ms/step - loss: 1.7831 - accuracy: 0.4543 - val_loss: 2.0762 - val_accuracy: 0.3994
# Epoch 68: Learning rate is 0.000233
# Epoch 68/100
# 491/491 [==============================] - 29s 59ms/step - loss: 1.7750 - accuracy: 0.4574 - val_loss: 2.0734 - val_accuracy: 0.3968
# Epoch 69: Learning rate is 0.000225
# Epoch 69/100
# 491/491 [==============================] - 31s 63ms/step - loss: 1.7672 - accuracy: 0.4581 - val_loss: 2.0690 - val_accuracy: 0.3951
# Epoch 70: Learning rate is 0.000218
# Epoch 70/100
# 491/491 [==============================] - 30s 60ms/step - loss: 1.7677 - accuracy: 0.4608 - val_loss: 2.0725 - val_accuracy: 0.3960
# Epoch 71: Learning rate is 0.000211
# Epoch 71/100
# 491/491 [==============================] - 29s 60ms/step - loss: 1.7565 - accuracy: 0.4628 - val_loss: 2.0795 - val_accuracy: 0.3951
# Epoch 72: Learning rate is 0.000205
# Epoch 72/100
# 491/491 [==============================] - 29s 60ms/step - loss: 1.7479 - accuracy: 0.4666 - val_loss: 2.0855 - val_accuracy: 0.3997
# Epoch 73: Learning rate is 0.000198
# Epoch 73/100
# 491/491 [==============================] - 25s 52ms/step - loss: 1.7412 - accuracy: 0.4692 - val_loss: 2.0743 - val_accuracy: 0.3989
# Epoch 74: Learning rate is 0.000191
# Epoch 74/100
# 491/491 [==============================] - 26s 53ms/step - loss: 1.7374 - accuracy: 0.4713 - val_loss: 2.0671 - val_accuracy: 0.4060
# Epoch 75: Learning rate is 0.000185
# Epoch 75/100
# 491/491 [==============================] - 26s 53ms/step - loss: 1.7283 - accuracy: 0.4701 - val_loss: 2.0746 - val_accuracy: 0.4052
# Epoch 76: Learning rate is 0.000179
# Epoch 76/100
# 491/491 [==============================] - 25s 51ms/step - loss: 1.7251 - accuracy: 0.4727 - val_loss: 2.0975 - val_accuracy: 0.3923
# Epoch 77: Learning rate is 0.000173
# Epoch 77/100
# 491/491 [==============================] - 25s 51ms/step - loss: 1.7201 - accuracy: 0.4745 - val_loss: 2.0914 - val_accuracy: 0.3980
# Epoch 78: Learning rate is 0.000167
# Epoch 78/100
# 491/491 [==============================] - 25s 51ms/step - loss: 1.7127 - accuracy: 0.4765 - val_loss: 2.0845 - val_accuracy: 0.3980
# Epoch 79: Learning rate is 0.000162
# Epoch 79/100
# 491/491 [==============================] - 23s 46ms/step - loss: 1.7099 - accuracy: 0.4778 - val_loss: 2.0657 - val_accuracy: 0.4132
# Epoch 80: Learning rate is 0.000157
# Epoch 80/100
# 491/491 [==============================] - 22s 44ms/step - loss: 1.7041 - accuracy: 0.4789 - val_loss: 2.0783 - val_accuracy: 0.3974
# Epoch 81: Learning rate is 0.000152
# Epoch 81/100
# 491/491 [==============================] - 22s 44ms/step - loss: 1.6965 - accuracy: 0.4809 - val_loss: 2.0780 - val_accuracy: 0.3960
# Epoch 82: Learning rate is 0.000147
# Epoch 82/100
# 491/491 [==============================] - 22s 44ms/step - loss: 1.6922 - accuracy: 0.4850 - val_loss: 2.0899 - val_accuracy: 0.3974
# Epoch 83: Learning rate is 0.000142
# Epoch 83/100
# 491/491 [==============================] - 22s 44ms/step - loss: 1.6860 - accuracy: 0.4857 - val_loss: 2.0862 - val_accuracy: 0.3934
# Epoch 84: Learning rate is 0.000138
# Epoch 84/100
# 491/491 [==============================] - 22s 44ms/step - loss: 1.6805 - accuracy: 0.4883 - val_loss: 2.0919 - val_accuracy: 0.3934
# Epoch 85: Learning rate is 0.000133
# Epoch 85/100
# 491/491 [==============================] - 22s 44ms/step - loss: 1.6747 - accuracy: 0.4890 - val_loss: 2.0993 - val_accuracy: 0.3974
# Epoch 86: Learning rate is 0.000129
# Epoch 86/100
# 491/491 [==============================] - 24s 48ms/step - loss: 1.6740 - accuracy: 0.4905 - val_loss: 2.0923 - val_accuracy: 0.4026
# Epoch 87: Learning rate is 0.000126
# Epoch 87/100
# 491/491 [==============================] - 26s 53ms/step - loss: 1.6672 - accuracy: 0.4892 - val_loss: 2.0975 - val_accuracy: 0.3957
# Epoch 88: Learning rate is 0.000122
# Epoch 88/100
# 491/491 [==============================] - 24s 49ms/step - loss: 1.6630 - accuracy: 0.4908 - val_loss: 2.1099 - val_accuracy: 0.3937
# Epoch 89: Learning rate is 0.000119
# Epoch 89/100
# 491/491 [==============================] - 24s 49ms/step - loss: 1.6588 - accuracy: 0.4930 - val_loss: 2.1163 - val_accuracy: 0.3971
# Epoch 90: Learning rate is 0.000116
# Epoch 90/100
# 491/491 [==============================] - 26s 54ms/step - loss: 1.6544 - accuracy: 0.4967 - val_loss: 2.1053 - val_accuracy: 0.4009
# Epoch 91: Learning rate is 0.000113
# Epoch 91/100
# 491/491 [==============================] - 26s 54ms/step - loss: 1.6542 - accuracy: 0.4925 - val_loss: 2.1258 - val_accuracy: 0.4043
# Epoch 92: Learning rate is 0.000111
# Epoch 92/100
# 491/491 [==============================] - 26s 52ms/step - loss: 1.6471 - accuracy: 0.4986 - val_loss: 2.0997 - val_accuracy: 0.4009
# Epoch 93: Learning rate is 0.000108
# Epoch 93/100
# 491/491 [==============================] - 28s 56ms/step - loss: 1.6447 - accuracy: 0.4980 - val_loss: 2.1036 - val_accuracy: 0.4034
# Epoch 94: Learning rate is 0.000107
# Epoch 94/100
# 491/491 [==============================] - 27s 54ms/step - loss: 1.6397 - accuracy: 0.5015 - val_loss: 2.1072 - val_accuracy: 0.3925
# Epoch 95: Learning rate is 0.000105
# Epoch 95/100
# 491/491 [==============================] - 23s 46ms/step - loss: 1.6364 - accuracy: 0.5007 - val_loss: 2.1045 - val_accuracy: 0.4037
# Epoch 96: Learning rate is 0.000103
# Epoch 96/100
# 491/491 [==============================] - 23s 46ms/step - loss: 1.6328 - accuracy: 0.5020 - val_loss: 2.1224 - val_accuracy: 0.4009
# Epoch 97: Learning rate is 0.000102
# Epoch 97/100
# 491/491 [==============================] - 23s 47ms/step - loss: 1.6333 - accuracy: 0.5007 - val_loss: 2.1094 - val_accuracy: 0.4037
# Epoch 98: Learning rate is 0.000101
# Epoch 98/100
# 491/491 [==============================] - 23s 47ms/step - loss: 1.6288 - accuracy: 0.5017 - val_loss: 2.1190 - val_accuracy: 0.3994
# Epoch 99: Learning rate is 0.000101
# Epoch 99/100
# 491/491 [==============================] - 23s 47ms/step - loss: 1.6282 - accuracy: 0.5024 - val_loss: 2.1190 - val_accuracy: 0.4009
# Epoch 100: Learning rate is 0.000100
# Epoch 100/100
# 491/491 [==============================] - 23s 47ms/step - loss: 1.6276 - accuracy: 0.5031 - val_loss: 2.1247 - val_accuracy: 0.3991

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, Activation
from tensorflow.keras import layers

def plot_layer_parameters(model):
    for layer in model.layers:
        if isinstance(layer, (Dense, Dropout)):
            # Handle Dense and Dropout layers
            if isinstance(layer, Dense):
                layer_weights = layer.get_weights()
                if len(layer_weights) >= 2:
                    weights = layer_weights[0]
                    biases = layer_weights[1]
                    print(f"Layer: {layer.name}")
                    print(f"Weights shape: {weights.shape}, Biases shape: {biases.shape}")
                    weight_variances = np.var(weights, axis=0)

                    plt.figure(figsize=(10, 5))
                    plt.bar(range(len(weight_variances)), weight_variances)
                    plt.title(f'Variance of Weights per Neuron in Layer {layer.name}')
                    plt.xlabel('Neuron Index')
                    plt.ylabel('Variance')
                    plt.show()

                    if len(biases.shape) == 1:
                        plt.figure(figsize=(10, 5))
                        plt.bar(range(len(biases)), biases)
                        plt.title(f'Biases in Layer {layer.name}')
                        plt.xlabel('Neuron Index')
                        plt.ylabel('Bias Value')
                        plt.show()
                else:
                    print(f"Layer {layer.name} does not have standard weights and biases.")
        
        elif isinstance(layer, LinearRecurrentUnit):
            # Handle LinearRecurrentUnit layer
            layer_weights = [
                layer.A.numpy(), layer.B.numpy(), layer.C.numpy(), layer.D.numpy()
            ]
            
            print(f"Layer: {layer.name}")
            for i, param in enumerate(layer_weights):
                param_name = ['A', 'B', 'C', 'D'][i]
                print(f"{param_name} shape: {param.shape}")
                
                # Plot the variance of each parameter
                weight_variances = np.var(param, axis=0)
                
                plt.figure(figsize=(10, 5))
                plt.bar(range(len(weight_variances)), weight_variances)
                plt.title(f'Variance of {param_name} in Layer {layer.name}')
                plt.xlabel('Neuron Index')
                plt.ylabel('Variance')
                plt.show()
        
        else:
            print(f"Layer {layer.name} is not a LinearRecurrentUnit, Dense, or Dropout layer.")

# Call the function with your model
plot_layer_parameters(model)
# Out:
# Layer: linear_recurrent_unit_17
# A shape: (128, 128)
# B shape: (47, 128)
# C shape: (128, 128)
# D shape: (47, 128)
# Layer: linear_recurrent_unit_18
# A shape: (128, 128)
# B shape: (128, 128)
# C shape: (128, 128)
# D shape: (128, 128)
# Layer: linear_recurrent_unit_19
# A shape: (128, 128)
# B shape: (128, 128)
# C shape: (128, 128)
# D shape: (128, 128)
# Layer: linear_recurrent_unit_20
# A shape: (128, 128)
# B shape: (128, 128)
# C shape: (128, 128)
# D shape: (128, 128)
# Layer lambda_3 is not a LinearRecurrentUnit, Dense, or Dropout layer.
# Layer: dense_3
# Weights shape: (128, 47), Biases shape: (47,)
# Layer activation_3 is not a LinearRecurrentUnit, Dense, or Dropout layer.

# %%
scores_train = model.evaluate(X_train, y_train, verbose=1)
scores_test = model.evaluate(X_test, y_test, verbose=1)
print(f"Performances (apprentissage, {model.metrics_names[1]}) = {scores_train[1]*100:.2f}")
print(f"Performances (validation, {model.metrics_names[1]}) = {scores_test[1]*100:.2f}")
# Out:
# 981/981 [==============================] - 8s 9ms/step - loss: 1.5620 - accuracy: 0.5232
# 109/109 [==============================] - 1s 9ms/step - loss: 2.1247 - accuracy: 0.3991
# Performances (apprentissage, accuracy) = 52.32
# Performances (validation, accuracy) = 39.91

# %%
#model_name = f"SimpleRNN_{h_size}_{num_epochs}epochs"
#model.save(model_name)

# %%
#from tensorflow.keras.models import load_model
#model = load_model(model_name)
#model.compile(loss='categorical_crossentropy', optimizer='RMSprop', metrics=['accuracy'])
#model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_5 (GRU)                 (None, 10, 128)           72576
#
#  gru_6 (GRU)                 (None, 128)               99072
#
#  dense_1 (Dense)             (None, 59)                7611
#
#  activation_1 (Activation)   (None, 59)                0
#
# =================================================================
# Total params: 179259 (700.23 KB)
# Trainable params: 179259 (700.23 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
idx = 10
# index2char permet de repasser de l'encodage one-hot au caractère du dictionnaire
initial_characters = [index2char[np.argmax(c)] for c in X_train[idx]]
initial_text = "".join(initial_characters)
print(f"La séquence n°{idx} est : '{initial_text}'")
# Out:
# La séquence n°10 est : 't faire ép'

# %%
test_sequence = np.zeros((1, SEQLEN, n_characters), dtype=bool)
test_sequence[0] = X_train[idx]
prediction = model.predict(test_sequence)
print(prediction)
# Out:
# 1/1 [==============================] - 2s 2s/step
# [[1.8248733e-02 4.2059270e-07 7.3798467e-10 6.4718555e-09 3.8619938e-09
#   1.0577313e-09 1.6948849e-10 3.8313569e-08 1.0206200e-11 7.4901774e-09
#   1.0005992e-01 5.5856910e-03 1.1780952e-04 2.0137802e-03 4.9452111e-02
#   2.8933942e-05 2.0511565e-05 9.3378210e-03 5.9414748e-02 4.0317448e-07
#   7.7861166e-09 3.5871366e-01 3.6897936e-03 1.9834398e-03 4.4138946e-02
#   4.5312213e-04 1.2771611e-06 2.7891737e-01 2.7329824e-03 8.2096194e-05
#   3.8917895e-02 3.8873433e-05 9.2307758e-08 1.2763051e-06 1.1352658e-04
#   1.0604935e-04 9.7435359e-06 3.1955060e-04 1.8767923e-07 5.2812034e-03
#   2.0171868e-02 2.2224065e-05 1.8814546e-06 6.4145710e-14 1.4300710e-05
#   7.7045001e-08 7.4745758e-06]]

# %%
def sample(probabilities, temperature=1.0):
    probabilities = np.asarray(probabilities).astype('float64')
    # Modifie la distribution selon la valeur de la température
    probabilities = pow(probabilities, 1.0/temperature)
    probabilities /= np.sum(probabilities)
    # Tire des variables aléatoires selon la distribution multinomiale transformée
    random_values = np.random.multinomial(1, probabilities, 1)
    # Renvoie le symbole échantillonné
    return np.argmax(random_values)

# %%
# Longueur du texte à générer (en caractères)
text_length = 200
# Température
temperature = 0.5

generated_text = initial_text
network_input = test_sequence

for i in range(text_length):
    last_characters = generated_text[-SEQLEN:]
    
    # Préparer l'entrée pour la prédiction
    test_sequence = np.zeros((1, SEQLEN, n_characters), dtype=bool)
    for t, char in enumerate(last_characters):
        test_sequence[0, t, char2index[char]] = 1
    
    # Prédiction du modèle
    prediction = model.predict(test_sequence, verbose=0)
    
    # Échantillonner un caractère à partir de la distribution de probabilité
    predicted_char_index = sample(prediction[0], temperature)
    predicted_char = index2char[predicted_char_index]
    
    # Ajouter le caractère prédit au texte généré
    generated_text += predicted_char

print("Texte généré:")
print(generated_text)
# Out:
# Texte généré:
# t faire éplus paroi sombre perve hore comme beauté nuit enferaient méterne aprésibre plute car implange vie persoi pois profond ples cour désir troute plint prendeur lenfreuse profond belle derrière ongerre étr

# %%
# Fonction de softmax
def softmax(logits):
    exp_logits = np.exp(logits - np.max(logits))  # Stabilité numérique
    return exp_logits / np.sum(exp_logits)

# Fonction de sampling avec température et top-k
def sample(preds, temperature=1.0, top_k=5):
    preds = np.asarray(preds).astype("float64")
    preds = np.log(preds + 1e-10) / temperature  # Appliquer température
    preds = softmax(preds)

    # Optionnel: Limiter aux k meilleures probabilités
    if top_k > 0:
        top_k_indices = np.argsort(preds)[-top_k:]
        preds_top_k = preds[top_k_indices]
        preds_top_k /= np.sum(preds_top_k)  # Renormaliser
        return np.random.choice(top_k_indices, p=preds_top_k)
    
    return np.random.choice(len(preds), p=preds)

# 3. Génération de texte avec self-probing et calcul de l'entropie
def generate_text_with_entropy(model, initial_text, text_length=200, temperature=0.7, num_samples=10, top_k=5):
    generated_texts = []
    entropies = []
    
    for _ in range(num_samples):
        generated_text = initial_text
        network_input = np.zeros((1, SEQLEN, n_characters), dtype=bool)
        for t, char in enumerate(initial_text):
            if char in char2index:
                network_input[0, t, char2index[char]] = 1
        
        for i in range(text_length):
            prediction = model.predict(network_input, verbose=0)[0]

            # Appliquer le sampling
            predicted_char_index = sample(prediction, temperature, top_k)
            predicted_char = index2char[predicted_char_index]
            
            # Ajouter le caractère prédit au texte généré
            generated_text += predicted_char
            
            # Mettre à jour l'entrée du réseau (Recréer plutôt que décaler)
            network_input = np.zeros((1, SEQLEN, n_characters), dtype=bool)
            last_chars = generated_text[-SEQLEN:]
            for t, char in enumerate(last_chars):
                if char in char2index:
                    network_input[0, t, char2index[char]] = 1
        
        generated_texts.append(generated_text)
        
        # Calcul de l'entropie sur la dernière sortie
        logits = model.predict(network_input, verbose=0)[0]
        probs = softmax(logits)  # Softmax appliqué correctement
        entropies.append(entropy(probs))
    
    return generated_texts, entropies

# Génération de texte avec self-probing et calcul de l'entropie
generated_texts, entropies = generate_text_with_entropy(model, initial_text, text_length=200, temperature=0.7, num_samples=10, top_k=5)

for i, (text, ent) in enumerate(zip(generated_texts, entropies)):
    print(f"Sample {i+1}:")
    print(text)
    print(f"Entropy: {ent:.4f}")
    print("-" * 80)
# Out:
# Sample 1:
# t faire éplollive beaut sournus défore comme froides pluire siter longues sourint leurs paresse peut cour deux resterne cest profond car vers corpe connières presque cette désirait lang ressent comme flée comme
# Entropy: 3.8320
# --------------------------------------------------------------------------------
# Sample 2:
# t faire épare paressent déchose pleure paresse fierté plésir seule comme flemprés vins corsté semblait puis dence cerves bourbelait soirs vaspe comme nott douleur dun sange lair comme remère sombre fleurs pois
# Entropy: 3.8495
# --------------------------------------------------------------------------------
# Sample 3:
# t faire éprend perai femme beauté dester sen charmant miron plit crimant coeur souverait longe main lingnie tout déposant saprès dantes sou pleure si parfume regarde cris profond deur quun vage prendre filo der
# Entropy: 3.8388
# --------------------------------------------------------------------------------
# Sample 4:
# t faire éplange pers désère solosasse coeur plaiens coeur flambre où rêvert charchers corp doute toul cest manges farte deur thouts plonce mi haine lenait lenfit parange mérait lorsque onge ronge sans postrands
# Entropy: 3.8303
# --------------------------------------------------------------------------------
# Sample 5:
# t faire éprésent mainte remples coeur mère saines douleurs sendint tout charbent si croit si plendent poète charme deux courers désoire souche désour rayage cendre lange fait parmes lais antis lant ples belle i
# Entropy: 3.8446
# --------------------------------------------------------------------------------
# Sample 6:
# t faire éplange fait soureuse pares voule comme nembre priters cres beau comme frottin couleurs resses charge plaissait lingige petté charle charment cende lit mésité passese prissante désir beauté coeur soidit
# Entropy: 3.8423
# --------------------------------------------------------------------------------
# Sample 7:
# t faire éplés linguge fait salair peut renardi beau vemm chair lentie parfement ples vant charmeur fait coeur vengu dans choque chaire désoleil saisent douterai tombe licher puissant souffle dont crendatte cres
# Entropy: 3.8463
# --------------------------------------------------------------------------------
# Sample 8:
# t faire éprélenve remplus courer lait monde comme baudelaire fauteuse fort mange sableur tout tenours pient mange douteur mains cont lange manges lintite comme lingurent lartu temp mente dit car ainsi bien leur
# Entropy: 3.8340
# --------------------------------------------------------------------------------
# Sample 9:
# t faire éplés pose conne comme conne cet ame dir plais appesse vers cestaité selles appalangs main solein dort comme lant pose ditile croit lenfer sou bruleus ressent parfume projeur beau dit poète mant peuple
# Entropy: 3.8496
# --------------------------------------------------------------------------------
# Sample 10:
# t faire épirautre poiste coeur comme prose dive puriète dencent bien dési comme linture comme cette désir subvre cherante corp cour crayaie baude cens comme bien leurs seurs minait poureau disait soirir pointe
# Entropy: 3.8496
# --------------------------------------------------------------------------------

# %%
entropies
# Out:
# [3.8319786,
#  3.8494902,
#  3.8387852,
#  3.8302953,
#  3.8446383,
#  3.8422797,
#  3.8463175,
#  3.8340456,
#  3.8496397,
#  3.8496237]

# %%
import random

def introduce_typos(text, error_rate=0.1):
    """Ajoute des erreurs aléatoires dans un texte avec un certain taux de bruit."""
    chars = list(text)
    for i in range(len(chars)):
        if random.random() < error_rate:
            chars[i] = random.choice("abcdefghijklmnopqrstuvwxyz")  # Substitue une lettre
    return "".join(chars)

# %%
def correct_text(model, noisy_text, char2index, index2char, SEQLEN, n_characters, temperature=0.5):
    """ Corrige un texte bruité en générant une version corrigée avec le modèle """
    corrected_text = noisy_text[:SEQLEN]  # Conserver le début intact
    for i in range(len(noisy_text) - SEQLEN):
        last_characters = corrected_text[-SEQLEN:]

        # Préparer l'entrée pour la prédiction
        test_sequence = np.zeros((1, SEQLEN, n_characters), dtype=bool)
        for t, char in enumerate(last_characters):
            if char in char2index:
                test_sequence[0, t, char2index[char]] = 1

        # Prédiction du modèle
        prediction = model.predict(test_sequence, verbose=0)

        # Échantillonner un caractère à partir de la distribution de probabilité
        predicted_char_index = sample(prediction[0], temperature)
        predicted_char = index2char[predicted_char_index]

        # Ajouter le caractère prédit au texte corrigé
        corrected_text += predicted_char

    return corrected_text

# %%
# Exemple
original_text = "Bonjour, comment allez-vous aujourd'hui ?"
noisy_text = introduce_typos(original_text, error_rate=0.15)

corrected_text = correct_text(model, noisy_text, char2index, index2char, SEQLEN, n_characters)

print(f"Texte original : {original_text}")
print("Texte bruité   :", noisy_text)
print("Texte corrigé  :", corrected_text)
# Out:
# Texte original : Bonjour, comment allez-vous aujourd'hui ?
# Texte bruité   : Bhnjour, comment allez-fous aujourd'hsi ?
# Texte corrigé  : Bhnjour, comme fait cours pare dien renfi

# %%
import Levenshtein

def character_error_rate(reference, hypothesis):
    """Calcule le CER (Character Error Rate)"""
    return Levenshtein.distance(reference, hypothesis) / len(reference)

def word_error_rate(reference, hypothesis):
    """Calcule le WER (Word Error Rate)"""
    ref_words = reference.split()
    hyp_words = hypothesis.split()
    return Levenshtein.distance(" ".join(ref_words), " ".join(hyp_words)) / len(ref_words)

cer = character_error_rate(original_text, corrected_text)
wer = word_error_rate(original_text, corrected_text)

print(f"CER : {cer:.2%}")
print(f"WER : {wer:.2%}")
# Out:
# CER : 60.98%
# WER : 500.00%
